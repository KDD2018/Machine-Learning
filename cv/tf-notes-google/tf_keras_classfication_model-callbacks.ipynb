# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import sklearn
import pandas as pd
import os
import sys
import time
import tensorflow as tf
from tensorflow import keras

print(tf.__version__)
print(sys.version_info)
for module in mpl, np, pd, sklearn, tf, keras:
    print(module.__name__, module.__version__)
# Out:
# 2.0.0
# sys.version_info(major=3, minor=6, micro=5, releaselevel='final', serial=0)
# matplotlib 3.1.0
# numpy 1.18.1
# pandas 0.24.2
# sklearn 0.20.1
# tensorflow 2.0.0
# tensorflow_core.keras 2.2.4-tf

# %%
fashion_mnist = keras.datasets.fashion_mnist
(x_train_all, y_train_all), (x_test, y_test) = fashion_mnist.load_data()

# %%
x_valid, x_train = x_train_all[:5000], x_train_all[5000:]
y_valid, y_train = y_train_all[:5000], y_train_all[5000:]
print(x_train_all.shape, y_train_all.shape)
print(x_train.shape, y_train.shape)
print(x_valid.shape, y_valid.shape)
print(x_test.shape, y_test.shape)
# Out:
# (60000, 28, 28) (60000,)
# (55000, 28, 28) (55000,)
# (5000, 28, 28) (5000,)
# (10000, 28, 28) (10000,)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train.astype(np.float32).reshape(-1,1)).reshape(-1, 28, 28)
x_valid_scaled = scaler.transform(x_valid.astype(np.float32).reshape(-1,1)).reshape(-1, 28, 28)
x_test_scaled = scaler.transform(x_test.astype(np.float32).reshape(-1,1)).reshape(-1, 28, 28)

# %%
model = keras.Sequential([
    keras.layers.Flatten(input_shape=[28, 28]),
    keras.layers.Dense(300, activation='relu'),
    keras.layers.Dense(100, activation='relu'),
    keras.layers.Dense(10, activation='softmax')
])

model.compile(loss='sparse_categorical_crossentropy',
              optimizer='sgd',
              metrics=['accuracy'])

# %%
log_dir = './logs'
if not os.path.exists(log_dir):
    os.mkdir(log_dir)
model_file = os.path.join(log_dir, 'fashion_mnist_model.h5')    

callbacks = [
    keras.callbacks.TensorBoard(log_dir),
    keras.callbacks.ModelCheckpoint(model_file, save_best_only=True),
    keras.callbacks.EarlyStopping(patience=5, min_delta=1e-3)
]
history = model.fit(x_train_scaled, y_train, epochs=20,
                    validation_data=(x_valid_scaled, y_valid),
                    callbacks=callbacks)
# Out:
# Train on 55000 samples, validate on 5000 samples
# Epoch 1/20
# 55000/55000 [==============================] - 3s 55us/sample - loss: 0.5390 - accuracy: 0.8107 - val_loss: 0.4152 - val_accuracy: 0.8562
# Epoch 2/20
# 55000/55000 [==============================] - 3s 49us/sample - loss: 0.3933 - accuracy: 0.8594 - val_loss: 0.3778 - val_accuracy: 0.8646
# Epoch 3/20
# 55000/55000 [==============================] - 3s 51us/sample - loss: 0.3544 - accuracy: 0.8730 - val_loss: 0.3598 - val_accuracy: 0.8690
# Epoch 4/20
# 55000/55000 [==============================] - 3s 51us/sample - loss: 0.3294 - accuracy: 0.8819 - val_loss: 0.3597 - val_accuracy: 0.8708
# Epoch 5/20
# 55000/55000 [==============================] - 3s 48us/sample - loss: 0.3111 - accuracy: 0.8866 - val_loss: 0.3274 - val_accuracy: 0.8848
# Epoch 6/20
# 55000/55000 [==============================] - 3s 48us/sample - loss: 0.2956 - accuracy: 0.8924 - val_loss: 0.3239 - val_accuracy: 0.8808
# Epoch 7/20
# 55000/55000 [==============================] - 3s 48us/sample - loss: 0.2803 - accuracy: 0.8986 - val_loss: 0.3068 - val_accuracy: 0.8880
# Epoch 8/20
# 55000/55000 [==============================] - 3s 48us/sample - loss: 0.2692 - accuracy: 0.9019 - val_loss: 0.3210 - val_accuracy: 0.8834
# Epoch 9/20
# 55000/55000 [==============================] - 3s 48us/sample - loss: 0.2570 - accuracy: 0.9064 - val_loss: 0.2989 - val_accuracy: 0.8928
# Epoch 10/20
# 55000/55000 [==============================] - 3s 48us/sample - loss: 0.2473 - accuracy: 0.9098 - val_loss: 0.3029 - val_accuracy: 0.8880
# Epoch 11/20
# 55000/55000 [==============================] - 3s 48us/sample - loss: 0.2379 - accuracy: 0.9126 - val_loss: 0.3031 - val_accuracy: 0.8902
# Epoch 12/20
# 55000/55000 [==============================] - 3s 50us/sample - loss: 0.2284 - accuracy: 0.9178 - val_loss: 0.2964 - val_accuracy: 0.8948
# Epoch 13/20
# 55000/55000 [==============================] - 3s 52us/sample - loss: 0.2205 - accuracy: 0.9190 - val_loss: 0.3041 - val_accuracy: 0.8906
# Epoch 14/20
# 55000/55000 [==============================] - 3s 49us/sample - loss: 0.2124 - accuracy: 0.9236 - val_loss: 0.2948 - val_accuracy: 0.8946
# Epoch 15/20
# 55000/55000 [==============================] - 3s 49us/sample - loss: 0.2050 - accuracy: 0.9265 - val_loss: 0.2997 - val_accuracy: 0.8922
# Epoch 16/20
# 55000/55000 [==============================] - 3s 49us/sample - loss: 0.1980 - accuracy: 0.9286 - val_loss: 0.2954 - val_accuracy: 0.8942
# Epoch 17/20
# 55000/55000 [==============================] - 3s 49us/sample - loss: 0.1915 - accuracy: 0.9311 - val_loss: 0.2889 - val_accuracy: 0.8954
# Epoch 18/20
# 55000/55000 [==============================] - 3s 49us/sample - loss: 0.1850 - accuracy: 0.9343 - val_loss: 0.3012 - val_accuracy: 0.8896
# Epoch 19/20
# 55000/55000 [==============================] - 3s 53us/sample - loss: 0.1787 - accuracy: 0.9363 - val_loss: 0.2938 - val_accuracy: 0.8942
# Epoch 20/20
# 55000/55000 [==============================] - 3s 49us/sample - loss: 0.1726 - accuracy: 0.9383 - val_loss: 0.2963 - val_accuracy: 0.8934

# %%
def plot_learning_curves(history):
    pd.DataFrame(history.history).plot(figsize=(8, 5))
    plt.grid(True)
    plt.gca().set_ylim(0,1)
    plt.show()
    
plot_learning_curves(history)

# %%
model.evaluate(x_test_scaled, y_test)
# Out:
# 10000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...
# [0.3352627127468586, 0.8872]

# %%
import tensorflow as tf
from tensorflow import keras

# %% [markdown]
# # 准备数据

# %%
def load_image(img_path, size=(32, 32)):
    label = tf.constant(1, tf.int8) if tf.strings.regex_full_match(img_path, ".*automobile.*") else tf.constant(0, tf.int8)
    img = tf.io.read_file(img_path)
    img = tf.image.decode_jpeg(img)
    img = tf.image.resize(img, size) / 255.0
    return img, label

# %%
BATCH_SIZE = 100
train_ds = tf.data.Dataset.list_files('/home/kdd/python/eat_tensorflow2_in_30_days/data/cifar2/train/*/*.jpg') \
           .map(load_image, num_parallel_calls=tf.data.experimental.AUTOTUNE) \
           .shuffle(buffer_size=1000).batch(BATCH_SIZE) \
           .prefetch(tf.data.experimental.AUTOTUNE)
test_ds = tf.data.Dataset.list_files('/home/kdd/python/eat_tensorflow2_in_30_days/data/cifar2/test/*/*.jpg') \
          .map(load_image, num_parallel_calls=tf.data.experimental.AUTOTUNE) \
          .batch(BATCH_SIZE) \
          .prefetch(tf.data.experimental.AUTOTUNE)

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'

# %%
from matplotlib import pyplot as plt

plt.figure(figsize=(8, 8))
for i, (img, label) in enumerate(train_ds.unbatch().take(9)):
    ax = plt.subplot(3, 3, i+1)
    ax.imshow(img.numpy())
    ax.set_title('label = %d'%label)
    ax.set_xticks([])
    ax.set_yticks([])
plt.show()

# %%
for x, y in train_ds.take(1):
    print(x.shape, y.shape)
# Out:
# (100, 32, 32, 3) (100,)

# %% [markdown]
# # 模型搭建与训练

# %%
tf.keras.backend.clear_session()

inputs = keras.layers.Input(shape=(32, 32, 3))
x = keras.layers.Conv2D(32, kernel_size=(3,3))(inputs)
x = keras.layers.MaxPool2D()(x)
x = keras.layers.Conv2D(64, kernel_size=(5, 5))(x)
x = keras.layers.MaxPool2D()(x)
x = keras.layers.Dropout(0.1)(x)
x = keras.layers.Flatten()(x)
x = keras.layers.Dense(32, activation='relu')(x)
outputs = keras.layers.Dense(1, activation='sigmoid')(x)

model = tf.keras.models.Model(inputs=inputs, outputs=outputs)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 32, 32, 3)]       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 30, 30, 32)        896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 11, 11, 64)        51264
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 5, 5, 64)          0
# _________________________________________________________________
# dropout (Dropout)            (None, 5, 5, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 1600)              0
# _________________________________________________________________
# dense (Dense)                (None, 32)                51232
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 103,425
# Trainable params: 103,425
# Non-trainable params: 0
# _________________________________________________________________

# %%
import datetime
import os
from pathlib import Path

stamp = datetime.datetime.now().strftime('%Y%m%d-%H%M%S')
log_dir = str(Path('../logs/' + stamp))

tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)

model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
              loss=tf.keras.losses.binary_crossentropy,
              metrics=['accuracy']
             )
history = model.fit(train_ds, epochs=20, validation_data=test_ds, callbacks=[tensorboard_callback], workers=4)
# Out:
# Train for 100 steps, validate for 20 steps
# Epoch 1/20
# 100/100 [==============================] - 5s 45ms/step - loss: 0.4725 - accuracy: 0.7703 - val_loss: 0.3337 - val_accuracy: 0.8555
# Epoch 2/20
# 100/100 [==============================] - 4s 38ms/step - loss: 0.3249 - accuracy: 0.8612 - val_loss: 0.2870 - val_accuracy: 0.8785
# Epoch 3/20
# 100/100 [==============================] - 4s 39ms/step - loss: 0.2636 - accuracy: 0.8907 - val_loss: 0.2302 - val_accuracy: 0.9060
# Epoch 4/20
# 100/100 [==============================] - 4s 41ms/step - loss: 0.2222 - accuracy: 0.9119 - val_loss: 0.1976 - val_accuracy: 0.9245
# Epoch 5/20
# 100/100 [==============================] - 4s 39ms/step - loss: 0.1894 - accuracy: 0.9252 - val_loss: 0.1832 - val_accuracy: 0.9265
# Epoch 6/20
# 100/100 [==============================] - 4s 38ms/step - loss: 0.1700 - accuracy: 0.9345 - val_loss: 0.1716 - val_accuracy: 0.9310
# Epoch 7/20
# 100/100 [==============================] - 4s 40ms/step - loss: 0.1464 - accuracy: 0.9456 - val_loss: 0.1589 - val_accuracy: 0.9360
# Epoch 8/20
# 100/100 [==============================] - 4s 38ms/step - loss: 0.1362 - accuracy: 0.9478 - val_loss: 0.1603 - val_accuracy: 0.9355
# Epoch 9/20
# 100/100 [==============================] - 4s 39ms/step - loss: 0.1142 - accuracy: 0.9548 - val_loss: 0.1604 - val_accuracy: 0.9320
# Epoch 10/20
# 100/100 [==============================] - 4s 39ms/step - loss: 0.1051 - accuracy: 0.9592 - val_loss: 0.1555 - val_accuracy: 0.9350
# Epoch 11/20
# 100/100 [==============================] - 4s 38ms/step - loss: 0.0864 - accuracy: 0.9677 - val_loss: 0.1923 - val_accuracy: 0.9310
# Epoch 12/20
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0830 - accuracy: 0.9672 - val_loss: 0.1671 - val_accuracy: 0.9350
# Epoch 13/20
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0657 - accuracy: 0.9772 - val_loss: 0.1689 - val_accuracy: 0.9360
# Epoch 14/20
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0548 - accuracy: 0.9815 - val_loss: 0.1726 - val_accuracy: 0.9390
# Epoch 15/20
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0516 - accuracy: 0.9809 - val_loss: 0.1937 - val_accuracy: 0.9340
# Epoch 16/20
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0454 - accuracy: 0.9845 - val_loss: 0.1850 - val_accuracy: 0.9390
# Epoch 17/20
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0417 - accuracy: 0.9859 - val_loss: 0.1925 - val_accuracy: 0.9380
# Epoch 18/20
# 100/100 [==============================] - 4s 38ms/step - loss: 0.0303 - accuracy: 0.9897 - val_loss: 0.1974 - val_accuracy: 0.9410
# Epoch 19/20
# 100/100 [==============================] - 4s 38ms/step - loss: 0.0283 - accuracy: 0.9919 - val_loss: 0.2124 - val_accuracy: 0.9365
# Epoch 20/20
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0260 - accuracy: 0.9915 - val_loss: 0.2242 - val_accuracy: 0.9395

# %% [markdown]
# # 评估模型

# %%
# %load_ext tensorboard

# %%
from tensorboard import notebook
notebook.list()
# Out:
# No known TensorBoard instances running.

# %%
notebook.start('--logdir ../logs/20200617-141242/')
# Out:
#       <iframe id="tensorboard-frame-b8f8c38961908f4e" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-b8f8c38961908f4e");
#           const url = new URL("/", window.location);
#           url.port = 6007;
#           frame.src = url;
#         })();
#       </script>

# %%
import pandas as pd
df_history = pd.DataFrame(history.history)
df_history.index = range(1, len(df_history) + 1)
df_history.index.name='epoch'

# %%
def plot_metric(history, metric):
    train_metric = history.history[metric]
    val_metric = history.history['val_'+metric]
    epochs = range(1, len(train_metric) + 1)
    plt.plot(epochs, train_metric, 'bo--')
    plt.plot(epochs, val_metric, 'ro--')
    plt.title('Train and Validation '+metric)
    plt.xlabel('Epochs')
    plt.ylabel(metric)
    plt.legend(['train_'+metric, 'val_'+metric])
    plt.show()

# %%
plot_metric(history, 'loss')

# %%
plot_metric(history, 'accuracy')

# %%
val_loss, val_acc = model.evaluate(test_ds, workers=4)
# Out:
# 20/20 [==============================] - 0s 14ms/step - loss: 0.2242 - accuracy: 0.9395

# %% [markdown]
# # 预测

# %%
model.predict(test_ds)
# Out:
# array([[9.9958295e-01],
#        [8.4203158e-08],
#        [8.3306378e-01],
#        ...,
#        [9.9962413e-01],
#        [2.6165853e-07],
#        [1.0000000e+00]], dtype=float32)

# %%
# 使用model.predict_on_batch对一个批量进行预测
for x, y in test_ds.take(1):
    print(model.predict_on_batch(x[:20]))
# Out:
# tf.Tensor(
# [[9.9997389e-01]
#  [9.9999917e-01]
#  [8.2333905e-08]
#  [9.9976224e-01]
#  [9.9999988e-01]
#  [9.9996281e-01]
#  [5.4218242e-07]
#  [9.9942017e-01]
#  [6.0053655e-09]
#  [3.7609609e-06]
#  [9.9999988e-01]
#  [1.9177018e-03]
#  [1.0511260e-03]
#  [2.1842353e-03]
#  [1.3804132e-03]
#  [9.6618706e-01]
#  [1.5672028e-07]
#  [9.9999833e-01]
#  [5.1986215e-05]
#  [9.9994743e-01]], shape=(20, 1), dtype=float32)

# %% [markdown]
# # 保存模型

# %%
# 仅保存权重张量
model.save_weights('../logs/tf_model_weights.ckpt', save_format='tf')

# %%
# 保存模型结构与模型参数到文件,该方式保存的模型具有跨平台性便于部署
model.save('../logs/tf_savedmodel', save_format='tf')
# Out:
# WARNING:tensorflow:From /home/kdd/anaconda3/envs/tf2.1/lib/python3.7/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1786: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# INFO:tensorflow:Assets written to: ../logs/tf_savedmodel/assets

# %%
model_load = tf.keras.models.load_model('../logs/tf_savedmodel/')
model_load.evaluate(test_ds)
# Out:
# 20/20 [==============================] - 0s 18ms/step - loss: 0.2241 - accuracy: 0.9395
# [0.22407420426607133, 0.9395]

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import sklearn
import pandas as pd
import os
import sys
import time
import tensorflow as tf
from tensorflow import keras
from sklearn.datasets import fetch_california_housing

print(tf.__version__)
print(sys.version_info)
for module in mpl, np, pd, sklearn, tf, keras:
    print(module.__name__, module.__version__)
# Out:
# 2.0.0
# sys.version_info(major=3, minor=6, micro=8, releaselevel='final', serial=0)
# matplotlib 3.1.1
# numpy 1.17.2
# pandas 0.25.3
# sklearn 0.21.3
# tensorflow 2.0.0
# tensorflow_core.keras 2.2.4-tf

# %%
house = fetch_california_housing()
print(house.DESCR)
# Out:
# .. _california_housing_dataset:
#
# California Housing dataset
# --------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 20640
#
#     :Number of Attributes: 8 numeric, predictive attributes and the target
#
#     :Attribute Information:
#         - MedInc        median income in block
#         - HouseAge      median house age in block
#         - AveRooms      average number of rooms
#         - AveBedrms     average number of bedrooms
#         - Population    block population
#         - AveOccup      average house occupancy
#         - Latitude      house block latitude
#         - Longitude     house block longitude
#
#     :Missing Attribute Values: None
#
# This dataset was obtained from the StatLib repository.
# http://lib.stat.cmu.edu/datasets/
#
# The target variable is the median house value for California districts.
#
# This dataset was derived from the 1990 U.S. census, using one row per census
# block group. A block group is the smallest geographical unit for which the U.S.
# Census Bureau publishes sample data (a block group typically has a population
# of 600 to 3,000 people).
#
# It can be downloaded/loaded using the
# :func:`sklearn.datasets.fetch_california_housing` function.
#
# .. topic:: References
#
#     - Pace, R. Kelley and Ronald Barry, Sparse Spatial Autoregressions,
#       Statistics and Probability Letters, 33 (1997) 291-297

# %%
house.data.shape, house.target.shape
# Out:
# ((20640, 8), (20640,))

# %%
from sklearn.model_selection import train_test_split

x_train_all, x_test, y_train_all, y_test = train_test_split(
    house.data, house.target, random_state=7)
x_train, x_valid, y_train, y_valid = train_test_split(
    x_train_all, y_train_all, random_state=11)
print(x_train.shape, y_train.shape)
print(x_test.shape, y_test.shape)
print(x_valid.shape, y_valid.shape)
# Out:
# (11610, 8) (11610,)
# (5160, 8) (5160,)
# (3870, 8) (3870,)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)
x_valid_scaled = scaler.transform(x_valid)
x_test_scaled = scaler.transform(x_test)

# %%
def customized_mse(y_true, y_pred):
    return tf.reduce_mean(tf.square(y_true - y_pred))

model = keras.Sequential([
    keras.layers.Dense(30, activation='relu', input_shape=x_train.shape[1:]),
    keras.layers.Dense(1)
])
model.summary()
model.compile(loss=customized_mse, optimizer='sgd', metrics=['mean_squared_error'])
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 30)                270
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 31
# =================================================================
# Total params: 301
# Trainable params: 301
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(x_train_scaled, y_train,
                   validation_data=(x_valid_scaled, y_valid),
                   epochs=100,
                   callbacks=[keras.callbacks.EarlyStopping(patience=5, min_delta=1e-3)])
# Out:
# Train on 11610 samples, validate on 3870 samples
# Epoch 1/100
# 11610/11610 [==============================] - 2s 193us/sample - loss: 0.8131 - mean_squared_error: 0.8131 - val_loss: 0.6324 - val_mean_squared_error: 0.6324
# Epoch 2/100
# 11610/11610 [==============================] - 1s 93us/sample - loss: 0.9396 - mean_squared_error: 0.9396 - val_loss: 0.5725 - val_mean_squared_error: 0.5725
# Epoch 3/100
# 11610/11610 [==============================] - 1s 88us/sample - loss: 0.4742 - mean_squared_error: 0.4742 - val_loss: 0.4542 - val_mean_squared_error: 0.4542
# Epoch 4/100
# 11610/11610 [==============================] - 1s 91us/sample - loss: 0.4217 - mean_squared_error: 0.4217 - val_loss: 0.4297 - val_mean_squared_error: 0.4297
# Epoch 5/100
# 11610/11610 [==============================] - 1s 92us/sample - loss: 0.4064 - mean_squared_error: 0.4064 - val_loss: 0.4171 - val_mean_squared_error: 0.4171
# Epoch 6/100
# 11610/11610 [==============================] - 1s 86us/sample - loss: 0.3974 - mean_squared_error: 0.3974 - val_loss: 0.4072 - val_mean_squared_error: 0.4072
# Epoch 7/100
# 11610/11610 [==============================] - 1s 86us/sample - loss: 0.3975 - mean_squared_error: 0.3975 - val_loss: 0.4138 - val_mean_squared_error: 0.4138
# Epoch 8/100
# 11610/11610 [==============================] - 2s 136us/sample - loss: 0.3926 - mean_squared_error: 0.3926 - val_loss: 0.4078 - val_mean_squared_error: 0.4078
# Epoch 9/100
# 11610/11610 [==============================] - 1s 93us/sample - loss: 0.3825 - mean_squared_error: 0.3825 - val_loss: 0.3970 - val_mean_squared_error: 0.3970
# Epoch 10/100
# 11610/11610 [==============================] - 1s 92us/sample - loss: 0.3783 - mean_squared_error: 0.3783 - val_loss: 0.3903 - val_mean_squared_error: 0.3903
# Epoch 11/100
# 11610/11610 [==============================] - 1s 82us/sample - loss: 0.3742 - mean_squared_error: 0.3742 - val_loss: 0.3867 - val_mean_squared_error: 0.3867
# Epoch 12/100
# 11610/11610 [==============================] - 1s 85us/sample - loss: 0.3700 - mean_squared_error: 0.3700 - val_loss: 0.3778 - val_mean_squared_error: 0.3778
# Epoch 13/100
# 11610/11610 [==============================] - 1s 84us/sample - loss: 0.3679 - mean_squared_error: 0.3679 - val_loss: 0.3788 - val_mean_squared_error: 0.3788
# Epoch 14/100
# 11610/11610 [==============================] - 1s 101us/sample - loss: 0.3643 - mean_squared_error: 0.3643 - val_loss: 0.3716 - val_mean_squared_error: 0.3716
# Epoch 15/100
# 11610/11610 [==============================] - 1s 99us/sample - loss: 0.3601 - mean_squared_error: 0.3601 - val_loss: 0.3728 - val_mean_squared_error: 0.3728
# Epoch 16/100
# 11610/11610 [==============================] - 1s 84us/sample - loss: 0.3614 - mean_squared_error: 0.3614 - val_loss: 0.3671 - val_mean_squared_error: 0.3671
# Epoch 17/100
# 11610/11610 [==============================] - 1s 84us/sample - loss: 0.3542 - mean_squared_error: 0.3542 - val_loss: 0.3661 - val_mean_squared_error: 0.3661
# Epoch 18/100
# 11610/11610 [==============================] - 1s 87us/sample - loss: 0.3524 - mean_squared_error: 0.3524 - val_loss: 0.3645 - val_mean_squared_error: 0.3645
# Epoch 19/100
# 11610/11610 [==============================] - 1s 85us/sample - loss: 0.3547 - mean_squared_error: 0.3547 - val_loss: 0.3589 - val_mean_squared_error: 0.3589
# Epoch 20/100
# 11610/11610 [==============================] - 1s 85us/sample - loss: 0.3466 - mean_squared_error: 0.3466 - val_loss: 0.3590 - val_mean_squared_error: 0.3590
# Epoch 21/100
# 11610/11610 [==============================] - 1s 84us/sample - loss: 0.3662 - mean_squared_error: 0.3662 - val_loss: 0.3653 - val_mean_squared_error: 0.3653
# Epoch 22/100
# 11610/11610 [==============================] - 1s 84us/sample - loss: 0.3453 - mean_squared_error: 0.3453 - val_loss: 0.3570 - val_mean_squared_error: 0.3570
# Epoch 23/100
# 11610/11610 [==============================] - 1s 84us/sample - loss: 0.3442 - mean_squared_error: 0.3442 - val_loss: 0.3558 - val_mean_squared_error: 0.3558
# Epoch 24/100
# 11610/11610 [==============================] - 1s 113us/sample - loss: 0.3383 - mean_squared_error: 0.3383 - val_loss: 0.3501 - val_mean_squared_error: 0.3501
# Epoch 25/100
# 11610/11610 [==============================] - 1s 91us/sample - loss: 0.3361 - mean_squared_error: 0.3361 - val_loss: 0.3496 - val_mean_squared_error: 0.3496
# Epoch 26/100
# 11610/11610 [==============================] - 1s 89us/sample - loss: 0.3383 - mean_squared_error: 0.3383 - val_loss: 0.3468 - val_mean_squared_error: 0.3468
# Epoch 27/100
# 11610/11610 [==============================] - 1s 95us/sample - loss: 0.3334 - mean_squared_error: 0.3334 - val_loss: 0.3438 - val_mean_squared_error: 0.3438
# Epoch 28/100
# 11610/11610 [==============================] - 1s 84us/sample - loss: 0.3327 - mean_squared_error: 0.3327 - val_loss: 0.3435 - val_mean_squared_error: 0.3435
# Epoch 29/100
# 11610/11610 [==============================] - 1s 85us/sample - loss: 0.3309 - mean_squared_error: 0.3309 - val_loss: 0.3477 - val_mean_squared_error: 0.3477
# Epoch 30/100
# 11610/11610 [==============================] - 1s 89us/sample - loss: 0.3278 - mean_squared_error: 0.3278 - val_loss: 0.3448 - val_mean_squared_error: 0.3448
# Epoch 31/100
# 11610/11610 [==============================] - 1s 96us/sample - loss: 0.3256 - mean_squared_error: 0.3256 - val_loss: 0.3464 - val_mean_squared_error: 0.3464
# Epoch 32/100
# 11610/11610 [==============================] - 1s 101us/sample - loss: 0.3320 - mean_squared_error: 0.3320 - val_loss: 0.3416 - val_mean_squared_error: 0.3416
# Epoch 33/100
# 11610/11610 [==============================] - 2s 138us/sample - loss: 0.3252 - mean_squared_error: 0.3252 - val_loss: 0.3420 - val_mean_squared_error: 0.3420
# Epoch 34/100
# 11610/11610 [==============================] - 1s 99us/sample - loss: 0.3239 - mean_squared_error: 0.3239 - val_loss: 0.3426 - val_mean_squared_error: 0.3426
# Epoch 35/100
# 11610/11610 [==============================] - 1s 84us/sample - loss: 0.3286 - mean_squared_error: 0.3286 - val_loss: 0.3436 - val_mean_squared_error: 0.3436
# Epoch 36/100
# 11610/11610 [==============================] - 1s 88us/sample - loss: 0.3253 - mean_squared_error: 0.3253 - val_loss: 0.3366 - val_mean_squared_error: 0.3366
# Epoch 37/100
# 11610/11610 [==============================] - 1s 87us/sample - loss: 0.3232 - mean_squared_error: 0.3232 - val_loss: 0.3405 - val_mean_squared_error: 0.3405
# Epoch 38/100
# 11610/11610 [==============================] - 1s 90us/sample - loss: 0.3212 - mean_squared_error: 0.3212 - val_loss: 0.3367 - val_mean_squared_error: 0.3367
# Epoch 39/100
# 11610/11610 [==============================] - 1s 91us/sample - loss: 0.3208 - mean_squared_error: 0.3208 - val_loss: 0.3365 - val_mean_squared_error: 0.3365
# Epoch 40/100
# 11610/11610 [==============================] - 1s 86us/sample - loss: 0.3396 - mean_squared_error: 0.3396 - val_loss: 0.3346 - val_mean_squared_error: 0.3346
# Epoch 41/100
# 11610/11610 [==============================] - 1s 84us/sample - loss: 0.3215 - mean_squared_error: 0.3215 - val_loss: 0.3337 - val_mean_squared_error: 0.3337
# Epoch 42/100
# 11610/11610 [==============================] - 1s 83us/sample - loss: 0.3229 - mean_squared_error: 0.3229 - val_loss: 0.3337 - val_mean_squared_error: 0.3337
# Epoch 43/100
# 11610/11610 [==============================] - 1s 90us/sample - loss: 0.3208 - mean_squared_error: 0.3208 - val_loss: 0.3345 - val_mean_squared_error: 0.3345
# Epoch 44/100
# 11610/11610 [==============================] - 1s 92us/sample - loss: 0.3198 - mean_squared_error: 0.3198 - val_loss: 0.3337 - val_mean_squared_error: 0.3337
# Epoch 45/100
# 11610/11610 [==============================] - 1s 81us/sample - loss: 0.3189 - mean_squared_error: 0.3189 - val_loss: 0.3303 - val_mean_squared_error: 0.3303
# Epoch 46/100
# 11610/11610 [==============================] - 1s 85us/sample - loss: 0.3272 - mean_squared_error: 0.3272 - val_loss: 0.3387 - val_mean_squared_error: 0.3387
# Epoch 47/100
# 11610/11610 [==============================] - 1s 84us/sample - loss: 0.3174 - mean_squared_error: 0.3174 - val_loss: 0.3344 - val_mean_squared_error: 0.3344
# Epoch 48/100
# 11610/11610 [==============================] - 1s 79us/sample - loss: 0.3175 - mean_squared_error: 0.3175 - val_loss: 0.3335 - val_mean_squared_error: 0.3335
# Epoch 49/100
# 11610/11610 [==============================] - 1s 76us/sample - loss: 0.3172 - mean_squared_error: 0.3172 - val_loss: 0.3311 - val_mean_squared_error: 0.3311
# Epoch 50/100
# 11610/11610 [==============================] - 1s 77us/sample - loss: 0.3142 - mean_squared_error: 0.3142 - val_loss: 0.3318 - val_mean_squared_error: 0.3318

# %%
def plot_learning_curves(history):
    pd.DataFrame(history.history).plot(figsize=(8,5))
    plt.grid(True)
    plt.gca().set_ylim(0,1)
    plt.show()
plot_learning_curves(history)

# %%
model.evaluate(x_test_scaled, y_test)
# Out:
# 5160/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================== ...
# [0.3328972988350447, 0.3328974]

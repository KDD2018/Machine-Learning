# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import sklearn
import pandas as pd
import os
import sys
import time
import tensorflow as tf
from tensorflow import keras
from sklearn.datasets import fetch_california_housing

print(tf.__version__)
print(sys.version_info)
for module in mpl, np, pd, sklearn, tf, keras:
    print(module.__name__, module.__version__)
# Out:
# 2.0.0
# sys.version_info(major=3, minor=6, micro=8, releaselevel='final', serial=0)
# matplotlib 3.1.1
# numpy 1.17.2
# pandas 0.25.3
# sklearn 0.21.3
# tensorflow 2.0.0
# tensorflow_core.keras 2.2.4-tf

# %%
house = fetch_california_housing()
print(house.DESCR)
# Out:
# .. _california_housing_dataset:
#
# California Housing dataset
# --------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 20640
#
#     :Number of Attributes: 8 numeric, predictive attributes and the target
#
#     :Attribute Information:
#         - MedInc        median income in block
#         - HouseAge      median house age in block
#         - AveRooms      average number of rooms
#         - AveBedrms     average number of bedrooms
#         - Population    block population
#         - AveOccup      average house occupancy
#         - Latitude      house block latitude
#         - Longitude     house block longitude
#
#     :Missing Attribute Values: None
#
# This dataset was obtained from the StatLib repository.
# http://lib.stat.cmu.edu/datasets/
#
# The target variable is the median house value for California districts.
#
# This dataset was derived from the 1990 U.S. census, using one row per census
# block group. A block group is the smallest geographical unit for which the U.S.
# Census Bureau publishes sample data (a block group typically has a population
# of 600 to 3,000 people).
#
# It can be downloaded/loaded using the
# :func:`sklearn.datasets.fetch_california_housing` function.
#
# .. topic:: References
#
#     - Pace, R. Kelley and Ronald Barry, Sparse Spatial Autoregressions,
#       Statistics and Probability Letters, 33 (1997) 291-297

# %%
from sklearn.model_selection import train_test_split

x_train_all, x_test, y_train_all, y_test = train_test_split(
    house.data, house.target, random_state=7)
x_train, x_valid, y_train, y_valid = train_test_split(
    x_train_all, y_train_all, random_state=11)
print(x_train.shape, y_train.shape)
print(x_test.shape, y_test.shape)
print(x_valid.shape, y_valid.shape)
# Out:
# (11610, 8) (11610,)
# (5160, 8) (5160,)
# (3870, 8) (3870,)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)
x_valid_scaled = scaler.transform(x_valid)
x_test_scaled = scaler.transform(x_test)

# %%
# fit函数功能
# 1、batch 遍历训练集 metric
   # 1.1、自动求导
# 2、在epoch结束 验证模型 metric
'''自定义fit函数功能'''

epochs = 100
batch_size = 32
steps_per_epoch = len(x_train_scaled) // batch_size
optimizer = keras.optimizers.SGD()
metric = keras.metrics.MeanSquaredError()

# 随机获取大小为batch_size的数据
def random_batch(x, y, batch_size=32):
    idx = np.random.randint(0, len(x), size=batch_size)
    return x[idx], y[idx]

model = keras.Sequential([
    keras.layers.Dense(30, activation='relu', input_shape=x_train.shape[1:]),
    keras.layers.Dense(1)
])

for epoch in range(epochs):
    # 每个epoch开始，需要重置metric,因为metric有累计功能
    metric.reset_states()
    for step in range(steps_per_epoch):
        x_batch, y_batch = random_batch(x_train_scaled, y_train, batch_size)
        with tf.GradientTape() as tape:
            y_pred = model(x_batch)
            # print(y_pred.shape)
            loss = tf.reduce_mean(keras.losses.mean_squared_error(y_batch, y_pred))
            metric(y_batch, y_pred)
        grads = tape.gradient(loss, model.variables)
        grads_and_vars = zip(grads, model.variables)
        optimizer.apply_gradients(grads_and_vars)
        print('\rEpoch: ', epoch, 'train mse: ', metric.result().numpy(), end='')
    y_valid_pred = model(x_valid_scaled)
    valid_loss = tf.reduce_mean(keras.losses.mean_squared_error(y_valid, y_valid_pred))
    print('\t', 'valid mse: ', valid_loss.numpy())
# Out:
# WARNING:tensorflow:Layer dense_2 is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# Epoch:  0 train mse:  1.407313	 valid mse:  1.4201005
# Epoch:  1 train mse:  1.2657403	 valid mse:  1.409331
# Epoch:  2 train mse:  1.3402644train mse:  1.3072693	 valid mse:  1.4254376
# Epoch:  3 train mse:  1.2558757train mse:  1.3010529 train mse:  1.2814355	 valid mse:  1.3929751
# Epoch:  4 train mse:  1.224916	 valid mse:  1.3928609
# Epoch:  5 train mse:  1.262725	 valid mse:  1.3905663
# Epoch:  6 train mse:  1.261968	 valid mse:  1.3879819
# Epoch:  7 train mse:  1.2245312	 valid mse:  1.3989451
# Epoch:  8 train mse:  1.2708373	 valid mse:  1.3902478
# Epoch:  9 train mse:  1.2732184	 valid mse:  1.3863736
# Epoch:  10 train mse:  1.243854	 valid mse:  1.3856089
# Epoch:  11 train mse:  1.2434818	 valid mse:  1.3855972
# Epoch:  12 train mse:  1.2524757	 valid mse:  1.3861297.2336897
# Epoch:  13 train mse:  1.2605307	 valid mse:  1.3852397
# Epoch:  14 train mse:  1.2339344	 valid mse:  1.3852205
# Epoch:  15 train mse:  1.25715747 1.245504	 valid mse:  1.3872459
# Epoch:  16 train mse:  1.2603174	 valid mse:  1.3957734
# Epoch:  17 train mse:  1.2287976	 valid mse:  1.385128
# Epoch:  18 train mse:  1.2227868	 valid mse:  1.3872399
# Epoch:  19 train mse:  1.27891355train mse:  1.2839953 1.2840568	 valid mse:  1.4094515
# Epoch:  20 train mse:  1.2476307	 valid mse:  1.3880446.2461267 1.2428596
# Epoch:  21 train mse:  1.2498351	 valid mse:  1.399676
# Epoch:  22 train mse:  1.3097135	 valid mse:  1.386384
# Epoch:  23 train mse:  1.2679924	 valid mse:  1.3847773
# Epoch:  24 train mse:  1.2390044	 valid mse:  1.3838525
# Epoch:  25 train mse:  1.2144935	 valid mse:  1.3854016
# Epoch:  26 train mse:  1.2733094	 valid mse:  1.3846747
# Epoch:  27 train mse:  1.26437031.2707101	 valid mse:  1.3872477
# Epoch:  28 train mse:  1.2931979train mse:  1.2751067train mse:  1.2900084	 valid mse:  1.383426
# Epoch:  29 train mse:  1.2644552 1.2869269 1.259284	 valid mse:  1.3860515
# Epoch:  30 train mse:  1.2541391	 valid mse:  1.383861
# Epoch:  31 train mse:  1.22761	 valid mse:  1.3850963
# Epoch:  32 train mse:  1.2690376	 valid mse:  1.3837744
# Epoch:  33 train mse:  1.2576898 train mse:  1.2709768	 valid mse:  1.390382
# Epoch:  34 train mse:  1.24731846	 valid mse:  1.3831427
# Epoch:  35 train mse:  1.2292333	 valid mse:  1.3861455
# Epoch:  36 train mse:  1.2323362	 valid mse:  1.3923495
# Epoch:  37 train mse:  1.2792125	 valid mse:  1.3838049
# Epoch:  38 train mse:  1.2404234	 valid mse:  1.3847142
# Epoch:  39 train mse:  1.2748262	 valid mse:  1.3849795
# Epoch:  40 train mse:  1.2722812 1.3017486	 valid mse:  1.3922058
# Epoch:  41 train mse:  1.2804095	 valid mse:  1.3882558
# Epoch:  42 train mse:  1.2323542	 valid mse:  1.38363591.2299165
# Epoch:  43 train mse:  1.2559597	 valid mse:  1.3847672
# Epoch:  44 train mse:  1.223389	 valid mse:  1.3868325
# Epoch:  45 train mse:  1.2658314	 valid mse:  1.3864695
# Epoch:  46 train mse:  1.2636801	 valid mse:  1.3927699
# Epoch:  47 train mse:  1.2363173	 valid mse:  1.3888011
# Epoch:  48 train mse:  1.2791139	 valid mse:  1.3873023
# Epoch:  49 train mse:  1.2745571 1.303571	 valid mse:  1.3855355
# Epoch:  50 train mse:  1.2716309 train mse:  1.2774992	 valid mse:  1.390288
# Epoch:  51 train mse:  1.231788	 valid mse:  1.388445
# Epoch:  52 train mse:  1.2574925	 valid mse:  1.3837333
# Epoch:  53 train mse:  1.2366893 1.2483177 train mse:  1.2363114	 valid mse:  1.3852443
# Epoch:  54 train mse:  1.228912	 valid mse:  1.3883088
# Epoch:  55 train mse:  1.2674327train mse:  1.2361968	 valid mse:  1.3834441
# Epoch:  56 train mse:  1.3017795	 valid mse:  1.3840145
# Epoch:  57 train mse:  1.2762269	 valid mse:  1.3837653
# Epoch:  58 train mse:  1.2695256	 valid mse:  1.384238
# Epoch:  59 train mse:  1.257878	 valid mse:  1.3866521
# Epoch:  60 train mse:  1.2392179	 valid mse:  1.3853593
# Epoch:  61 train mse:  1.2525967	 valid mse:  1.3833482
# Epoch:  62 train mse:  1.2796559	 valid mse:  1.3841629
# Epoch:  63 train mse:  1.2628942	 valid mse:  1.3895986
# Epoch:  64 train mse:  1.2458556	 valid mse:  1.3916886
# Epoch:  65 train mse:  1.2525355	 valid mse:  1.3862897
# Epoch:  66 train mse:  1.2191359	 valid mse:  1.3963283
# Epoch:  67 train mse:  1.2518373	 valid mse:  1.3862216
# Epoch:  68 train mse:  1.2543781	 valid mse:  1.3849394
# Epoch:  69 train mse:  1.2407286	 valid mse:  1.390947
# Epoch:  70 train mse:  1.2524865	 valid mse:  1.3952198
# Epoch:  71 train mse:  1.2455504	 valid mse:  1.3828987
# Epoch:  72 train mse:  1.2462708	 valid mse:  1.3946167
# Epoch:  73 train mse:  1.2610343	 valid mse:  1.3842292
# Epoch:  74 train mse:  1.230657	 valid mse:  1.3912266
# Epoch:  75 train mse:  1.2380577	 valid mse:  1.3833286
# Epoch:  76 train mse:  1.2688423	 valid mse:  1.3855703
# Epoch:  77 train mse:  1.2641442	 valid mse:  1.384144
# Epoch:  78 train mse:  1.2871524	 valid mse:  1.3994275
# Epoch:  79 train mse:  1.2604254	 valid mse:  1.3853856
# Epoch:  80 train mse:  1.274642	 valid mse:  1.3844672
# Epoch:  81 train mse:  1.2447238	 valid mse:  1.3956302
# Epoch:  82 train mse:  1.2518144	 valid mse:  1.3835188
# Epoch:  83 train mse:  1.261621	 valid mse:  1.384723
# Epoch:  84 train mse:  1.2433615	 valid mse:  1.387225
# Epoch:  85 train mse:  1.2773927	 valid mse:  1.3836057
# Epoch:  86 train mse:  1.2783382	 valid mse:  1.3848826
# Epoch:  87 train mse:  1.25755	 valid mse:  1.3858595
# Epoch:  88 train mse:  1.277613	 valid mse:  1.3828824
# Epoch:  89 train mse:  1.2521458	 valid mse:  1.3976955
# Epoch:  90 train mse:  1.2166586	 valid mse:  1.38624332197796
# Epoch:  91 train mse:  1.275303	 valid mse:  1.3837638
# Epoch:  92 train mse:  1.2507967	 valid mse:  1.3833004
# Epoch:  93 train mse:  1.2591443 1.25732	 valid mse:  1.3831255
# Epoch:  94 train mse:  1.2480938	 valid mse:  1.3853217
# Epoch:  95 train mse:  1.2306718	 valid mse:  1.3850046
# Epoch:  96 train mse:  1.2366545	 valid mse:  1.3882012
# Epoch:  97 train mse:  1.2429866	 valid mse:  1.3875262
# Epoch:  98 train mse:  1.24682127	 valid mse:  1.3833685
# Epoch:  99 train mse:  1.2957973	 valid mse:  1.3827169

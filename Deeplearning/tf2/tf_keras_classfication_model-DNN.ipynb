# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import sklearn
import pandas as pd
import os
import sys
import time
import tensorflow as tf
from tensorflow import keras

print(tf.__version__)
print(sys.version_info)
for module in mpl, np, pd, sklearn, tf, keras:
    print(module.__name__, module.__version__)
# Out:
# 2.0.0
# sys.version_info(major=3, minor=6, micro=5, releaselevel='final', serial=0)
# matplotlib 3.1.0
# numpy 1.18.1
# pandas 0.24.2
# sklearn 0.20.1
# tensorflow 2.0.0
# tensorflow_core.keras 2.2.4-tf

# %%
fashion_mnist = keras.datasets.fashion_mnist
(x_train_all, y_train_all), (x_test, y_test) = fashion_mnist.load_data()

# %%
x_valid, x_train = x_train_all[:5000], x_train_all[5000:]
y_valid, y_train = y_train_all[:5000], y_train_all[5000:]
print(x_train_all.shape, y_train_all.shape)
print(x_train.shape, y_train.shape)
print(x_valid.shape, y_valid.shape)
print(x_test.shape, y_test.shape)
# Out:
# (60000, 28, 28) (60000,)
# (55000, 28, 28) (55000,)
# (5000, 28, 28) (5000,)
# (10000, 28, 28) (10000,)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train.astype(np.float32).reshape(-1,1)).reshape(-1, 28, 28)
x_valid_scaled = scaler.transform(x_valid.astype(np.float32).reshape(-1,1)).reshape(-1, 28, 28)
x_test_scaled = scaler.transform(x_test.astype(np.float32).reshape(-1,1)).reshape(-1, 28, 28)

# %%
'''
model = keras.Sequential([
    keras.layers.Flatten(input_shape=[28, 28]),
    keras.layers.Dense(300, activation='relu'),
    keras.layers.Dense(100, activation='relu'),
    keras.layers.Dense(10, activation='softmax')
])
'''
model = keras.models.Sequential()
model.add(keras.layers.Flatten(input_shape=[28, 28]))
for _ in range(20):
    model.add(keras.layers.Dense(100, activation='relu'))
model.add(keras.layers.Dense(10, activation='softmax'))

model.compile(loss='sparse_categorical_crossentropy',
             optimizer='sgd',
             metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten (Flatten)            (None, 784)               0
# _________________________________________________________________
# dense (Dense)                (None, 100)               78500
# _________________________________________________________________
# dense_1 (Dense)              (None, 100)               10100
# _________________________________________________________________
# dense_2 (Dense)              (None, 100)               10100
# _________________________________________________________________
# dense_3 (Dense)              (None, 100)               10100
# _________________________________________________________________
# dense_4 (Dense)              (None, 100)               10100
# _________________________________________________________________
# dense_5 (Dense)              (None, 100)               10100
# _________________________________________________________________
# dense_6 (Dense)              (None, 100)               10100
# _________________________________________________________________
# dense_7 (Dense)              (None, 100)               10100
# _________________________________________________________________
# dense_8 (Dense)              (None, 100)               10100
# _________________________________________________________________
# dense_9 (Dense)              (None, 100)               10100
# _________________________________________________________________
# dense_10 (Dense)             (None, 100)               10100
# _________________________________________________________________
# dense_11 (Dense)             (None, 100)               10100
# _________________________________________________________________
# dense_12 (Dense)             (None, 100)               10100
# _________________________________________________________________
# dense_13 (Dense)             (None, 100)               10100
# _________________________________________________________________
# dense_14 (Dense)             (None, 100)               10100
# _________________________________________________________________
# dense_15 (Dense)             (None, 100)               10100
# _________________________________________________________________
# dense_16 (Dense)             (None, 100)               10100
# _________________________________________________________________
# dense_17 (Dense)             (None, 100)               10100
# _________________________________________________________________
# dense_18 (Dense)             (None, 100)               10100
# _________________________________________________________________
# dense_19 (Dense)             (None, 100)               10100
# _________________________________________________________________
# dense_20 (Dense)             (None, 10)                1010
# =================================================================
# Total params: 271,410
# Trainable params: 271,410
# Non-trainable params: 0
# _________________________________________________________________

# %%
log_dir = './logs'
if not os.path.exists(log_dir):
    os.mkdir(log_dir)
model_file = os.path.join(log_dir, 'fashion_mnist_model.h5')    

callbacks = [
    keras.callbacks.TensorBoard(log_dir),
    keras.callbacks.ModelCheckpoint(model_file, save_best_only=True),
    keras.callbacks.EarlyStopping(patience=5, min_delta=1e-3)
]
history = model.fit(x_train_scaled, y_train, epochs=20,
                    validation_data=(x_valid_scaled, y_valid),
                   callbacks=callbacks)
# Out:
# Train on 55000 samples, validate on 5000 samples
# Epoch 1/20
# 55000/55000 [==============================] - 5s 89us/sample - loss: 1.9166 - accuracy: 0.2901 - val_loss: 1.0613 - val_accuracy: 0.4892
# Epoch 2/20
# 55000/55000 [==============================] - 4s 77us/sample - loss: 0.8301 - accuracy: 0.6586 - val_loss: 0.6421 - val_accuracy: 0.7502
# Epoch 3/20
# 55000/55000 [==============================] - 4s 80us/sample - loss: 0.5882 - accuracy: 0.7775 - val_loss: 0.5207 - val_accuracy: 0.8088
# Epoch 4/20
# 55000/55000 [==============================] - 4s 78us/sample - loss: 0.5043 - accuracy: 0.8189 - val_loss: 0.4616 - val_accuracy: 0.8440
# Epoch 5/20
# 55000/55000 [==============================] - 4s 77us/sample - loss: 0.4538 - accuracy: 0.8412 - val_loss: 0.4402 - val_accuracy: 0.8542
# Epoch 6/20
# 55000/55000 [==============================] - 4s 81us/sample - loss: 0.4188 - accuracy: 0.8542 - val_loss: 0.4061 - val_accuracy: 0.8656
# Epoch 7/20
# 55000/55000 [==============================] - 5s 82us/sample - loss: 0.3925 - accuracy: 0.8644 - val_loss: 0.4366 - val_accuracy: 0.8482
# Epoch 8/20
# 55000/55000 [==============================] - 5s 84us/sample - loss: 0.3675 - accuracy: 0.8725 - val_loss: 0.3846 - val_accuracy: 0.8714
# Epoch 9/20
# 55000/55000 [==============================] - 5s 84us/sample - loss: 0.3518 - accuracy: 0.8773 - val_loss: 0.4163 - val_accuracy: 0.8638
# Epoch 10/20
# 55000/55000 [==============================] - 5s 83us/sample - loss: 0.3323 - accuracy: 0.8855 - val_loss: 0.3729 - val_accuracy: 0.8744
# Epoch 11/20
# 55000/55000 [==============================] - 4s 75us/sample - loss: 0.3200 - accuracy: 0.8881 - val_loss: 0.3624 - val_accuracy: 0.8774
# Epoch 12/20
# 55000/55000 [==============================] - 4s 71us/sample - loss: 0.3090 - accuracy: 0.8917 - val_loss: 0.3826 - val_accuracy: 0.8702
# Epoch 13/20
# 55000/55000 [==============================] - 4s 79us/sample - loss: 0.2924 - accuracy: 0.8971 - val_loss: 0.3646 - val_accuracy: 0.8712
# Epoch 14/20
# 55000/55000 [==============================] - 4s 77us/sample - loss: 0.2812 - accuracy: 0.9007 - val_loss: 0.3411 - val_accuracy: 0.8804
# Epoch 15/20
# 55000/55000 [==============================] - 4s 72us/sample - loss: 0.2745 - accuracy: 0.9028 - val_loss: 0.3701 - val_accuracy: 0.8770
# Epoch 16/20
# 55000/55000 [==============================] - 4s 75us/sample - loss: 0.2648 - accuracy: 0.9055 - val_loss: 0.3469 - val_accuracy: 0.8784
# Epoch 17/20
# 55000/55000 [==============================] - 4s 78us/sample - loss: 0.2547 - accuracy: 0.9093 - val_loss: 0.3557 - val_accuracy: 0.8784
# Epoch 18/20
# 55000/55000 [==============================] - 4s 71us/sample - loss: 0.2464 - accuracy: 0.9117 - val_loss: 0.4562 - val_accuracy: 0.8574
# Epoch 19/20
# 55000/55000 [==============================] - 4s 76us/sample - loss: 0.2396 - accuracy: 0.9137 - val_loss: 0.3459 - val_accuracy: 0.8824

# %%
def plot_learning_curves(history):
    pd.DataFrame(history.history).plot(figsize=(8, 5))
    plt.grid(True)
    plt.gca().set_ylim(0,2)
    plt.show()
    
plot_learning_curves(history)

# %%
model.evaluate(x_test_scaled, y_test)
# Out:
# 10000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...
# [0.3625403270661831, 0.8774]

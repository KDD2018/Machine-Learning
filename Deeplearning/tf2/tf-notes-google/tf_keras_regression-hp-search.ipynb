# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import sklearn
import pandas as pd
import os
import sys
import time
import tensorflow as tf
from tensorflow import keras
from sklearn.datasets import fetch_california_housing

print(tf.__version__)
print(sys.version_info)
for module in mpl, np, pd, sklearn, tf, keras:
    print(module.__name__, module.__version__)
# Out:
# 2.0.0
# sys.version_info(major=3, minor=6, micro=8, releaselevel='final', serial=0)
# matplotlib 3.1.1
# numpy 1.17.2
# pandas 0.25.3
# sklearn 0.21.3
# tensorflow 2.0.0
# tensorflow_core.keras 2.2.4-tf

# %%
house = fetch_california_housing()
print(house.DESCR)
# Out:
# .. _california_housing_dataset:
#
# California Housing dataset
# --------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 20640
#
#     :Number of Attributes: 8 numeric, predictive attributes and the target
#
#     :Attribute Information:
#         - MedInc        median income in block
#         - HouseAge      median house age in block
#         - AveRooms      average number of rooms
#         - AveBedrms     average number of bedrooms
#         - Population    block population
#         - AveOccup      average house occupancy
#         - Latitude      house block latitude
#         - Longitude     house block longitude
#
#     :Missing Attribute Values: None
#
# This dataset was obtained from the StatLib repository.
# http://lib.stat.cmu.edu/datasets/
#
# The target variable is the median house value for California districts.
#
# This dataset was derived from the 1990 U.S. census, using one row per census
# block group. A block group is the smallest geographical unit for which the U.S.
# Census Bureau publishes sample data (a block group typically has a population
# of 600 to 3,000 people).
#
# It can be downloaded/loaded using the
# :func:`sklearn.datasets.fetch_california_housing` function.
#
# .. topic:: References
#
#     - Pace, R. Kelley and Ronald Barry, Sparse Spatial Autoregressions,
#       Statistics and Probability Letters, 33 (1997) 291-297

# %%
house.data.shape, house.target.shape
# Out:
# ((20640, 8), (20640,))

# %%
from sklearn.model_selection import train_test_split

x_train_all, x_test, y_train_all, y_test = train_test_split(
    house.data, house.target, random_state=7)
x_train, x_valid, y_train, y_valid = train_test_split(
    x_train_all, y_train_all, random_state=11)
print(x_train.shape, y_train.shape)
print(x_test.shape, y_test.shape)
print(x_valid.shape, y_valid.shape)
# Out:
# (11610, 8) (11610,)
# (5160, 8) (5160,)
# (3870, 8) (3870,)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)
x_valid_scaled = scaler.transform(x_valid)
x_test_scaled = scaler.transform(x_test)

# %%
# 手动实现学习率的超参数搜索
learning_rate = [1e-4, 3e-4, 1e-3, 3e-3, 1e-2, 3e-2]

histories = []
for lr in learning_rate:
    model = keras.Sequential([
        keras.layers.Dense(30, activation='relu', input_shape=x_train.shape[1:]),
        keras.layers.Dense(1)
    ])
    optimizer = keras.optimizers.SGD(lr)
    model.compile(loss='mean_squared_error', optimizer=optimizer)
    history = model.fit(x_train_scaled, y_train,
                        validation_data=(x_valid_scaled, y_valid),
                        epochs=100,
                        callbacks=[keras.callbacks.EarlyStopping(patience=5, min_delta=1e-2)])
    histories.append(history)
# Out:
# Train on 11610 samples, validate on 3870 samples
# Epoch 1/100
# 11610/11610 [==============================] - 2s 146us/sample - loss: 3.2746 - val_loss: 2.8671
# Epoch 2/100
# 11610/11610 [==============================] - 1s 75us/sample - loss: 2.3121 - val_loss: 2.1214
# Epoch 3/100
# 11610/11610 [==============================] - 1s 97us/sample - loss: 1.7312 - val_loss: 1.6637
# Epoch 4/100
# 11610/11610 [==============================] - 1s 76us/sample - loss: 1.3769 - val_loss: 1.3786
# Epoch 5/100
# 11610/11610 [==============================] - 1s 76us/sample - loss: 1.1573 - val_loss: 1.1986
# Epoch 6/100
# 11610/11610 [==============================] - 1s 77us/sample - loss: 1.0202 - val_loss: 1.0830
# Epoch 7/100
# 11610/11610 [==============================] - 1s 78us/sample - loss: 0.9328 - val_loss: 1.0064
# Epoch 8/100
# 11610/11610 [==============================] - 1s 82us/sample - loss: 0.8755 - val_loss: 0.9543
# Epoch 9/100
# 11610/11610 [==============================] - 1s 106us/sample - loss: 0.8367 - val_loss: 0.9175
# Epoch 10/100
# 11610/11610 [==============================] - 1s 78us/sample - loss: 0.8094 - val_loss: 0.8909
# Epoch 11/100
# 11610/11610 [==============================] - 1s 77us/sample - loss: 0.7896 - val_loss: 0.8709
# Epoch 12/100
# 11610/11610 [==============================] - 1s 76us/sample - loss: 0.7746 - val_loss: 0.8553
# Epoch 13/100
# 11610/11610 [==============================] - 1s 76us/sample - loss: 0.7628 - val_loss: 0.8424
# Epoch 14/100
# 11610/11610 [==============================] - 1s 79us/sample - loss: 0.7532 - val_loss: 0.8319
# Epoch 15/100
# 11610/11610 [==============================] - 1s 80us/sample - loss: 0.7451 - val_loss: 0.8227
# Epoch 16/100
# 11610/11610 [==============================] - 1s 75us/sample - loss: 0.7380 - val_loss: 0.8146
# Epoch 17/100
# 11610/11610 [==============================] - 1s 78us/sample - loss: 0.7316 - val_loss: 0.8075
# Epoch 18/100
# 11610/11610 [==============================] - 1s 77us/sample - loss: 0.7259 - val_loss: 0.8008
# Epoch 19/100
# 11610/11610 [==============================] - 1s 78us/sample - loss: 0.7206 - val_loss: 0.7947
# Epoch 20/100
# 11610/11610 [==============================] - 1s 79us/sample - loss: 0.7156 - val_loss: 0.7890
# Epoch 21/100
# 11610/11610 [==============================] - 1s 82us/sample - loss: 0.7108 - val_loss: 0.7836
# Epoch 22/100
# 11610/11610 [==============================] - 1s 76us/sample - loss: 0.7063 - val_loss: 0.7785
# Epoch 23/100
# 11610/11610 [==============================] - 1s 79us/sample - loss: 0.7020 - val_loss: 0.7736
# Epoch 24/100
# 11610/11610 [==============================] - 1s 78us/sample - loss: 0.6978 - val_loss: 0.7688
# Epoch 25/100
# 11610/11610 [==============================] - 1s 78us/sample - loss: 0.6938 - val_loss: 0.7643
# Epoch 26/100
# 11610/11610 [==============================] - 1s 81us/sample - loss: 0.6899 - val_loss: 0.7599
# Epoch 27/100
# 11610/11610 [==============================] - 1s 77us/sample - loss: 0.6861 - val_loss: 0.7556
# Epoch 28/100
# 11610/11610 [==============================] - 1s 86us/sample - loss: 0.6825 - val_loss: 0.7515
# Epoch 29/100
# 11610/11610 [==============================] - 1s 88us/sample - loss: 0.6789 - val_loss: 0.7475
# Epoch 30/100
# 11610/11610 [==============================] - 1s 89us/sample - loss: 0.6753 - val_loss: 0.7436
# Epoch 31/100
# 11610/11610 [==============================] - 1s 83us/sample - loss: 0.6719 - val_loss: 0.7399
# Epoch 32/100
# 11610/11610 [==============================] - 1s 80us/sample - loss: 0.6686 - val_loss: 0.7361
# Epoch 33/100
# 11610/11610 [==============================] - 1s 89us/sample - loss: 0.6653 - val_loss: 0.7325
# Epoch 34/100
# 11610/11610 [==============================] - 1s 89us/sample - loss: 0.6621 - val_loss: 0.7291
# Epoch 35/100
# 11610/11610 [==============================] - 1s 81us/sample - loss: 0.6590 - val_loss: 0.7256
# Epoch 36/100
# 11610/11610 [==============================] - 1s 78us/sample - loss: 0.6559 - val_loss: 0.7222
# Epoch 37/100
# 11610/11610 [==============================] - 1s 76us/sample - loss: 0.6529 - val_loss: 0.7189
# Epoch 38/100
# 11610/11610 [==============================] - 1s 80us/sample - loss: 0.6500 - val_loss: 0.7157
# Epoch 39/100
# 11610/11610 [==============================] - 1s 78us/sample - loss: 0.6471 - val_loss: 0.7126
# Epoch 40/100
# 11610/11610 [==============================] - 1s 77us/sample - loss: 0.6443 - val_loss: 0.7094
# Epoch 41/100
# 11610/11610 [==============================] - 1s 76us/sample - loss: 0.6416 - val_loss: 0.7064
# Epoch 42/100
# 11610/11610 [==============================] - 1s 79us/sample - loss: 0.6389 - val_loss: 0.7034
# Epoch 43/100
# 11610/11610 [==============================] - 1s 78us/sample - loss: 0.6362 - val_loss: 0.7005
# Epoch 44/100
# 11610/11610 [==============================] - 1s 78us/sample - loss: 0.6336 - val_loss: 0.6976
# Epoch 45/100
# 11610/11610 [==============================] - 1s 78us/sample - loss: 0.6310 - val_loss: 0.6947
# Epoch 46/100
# 11610/11610 [==============================] - 1s 80us/sample - loss: 0.6285 - val_loss: 0.6920
# Epoch 47/100
# 11610/11610 [==============================] - 1s 79us/sample - loss: 0.6261 - val_loss: 0.6892
# Epoch 48/100
# 11610/11610 [==============================] - 1s 77us/sample - loss: 0.6236 - val_loss: 0.6866
# Epoch 49/100
# 11610/11610 [==============================] - 1s 79us/sample - loss: 0.6212 - val_loss: 0.6839
# Epoch 50/100
# 11610/11610 [==============================] - 1s 79us/sample - loss: 0.6189 - val_loss: 0.6813
# Epoch 51/100
# 11610/11610 [==============================] - 1s 76us/sample - loss: 0.6166 - val_loss: 0.6787
# Epoch 52/100
# 11610/11610 [==============================] - 1s 76us/sample - loss: 0.6143 - val_loss: 0.6761
# Epoch 53/100
# 11610/11610 [==============================] - 1s 79us/sample - loss: 0.6121 - val_loss: 0.6737
# Epoch 54/100
# 11610/11610 [==============================] - 1s 78us/sample - loss: 0.6099 - val_loss: 0.6712
# Epoch 55/100
# 11610/11610 [==============================] - 1s 77us/sample - loss: 0.6077 - val_loss: 0.6688
# Epoch 56/100
# 11610/11610 [==============================] - 1s 77us/sample - loss: 0.6056 - val_loss: 0.6665
# Epoch 57/100
# 11610/11610 [==============================] - 1s 76us/sample - loss: 0.6035 - val_loss: 0.6641
# Epoch 58/100
# 11610/11610 [==============================] - 1s 78us/sample - loss: 0.6014 - val_loss: 0.6617
# Epoch 59/100
# 11610/11610 [==============================] - 1s 76us/sample - loss: 0.5993 - val_loss: 0.6594
# Epoch 60/100
# 11610/11610 [==============================] - 1s 78us/sample - loss: 0.5973 - val_loss: 0.6572
# Epoch 61/100
# 11610/11610 [==============================] - 1s 76us/sample - loss: 0.5953 - val_loss: 0.6549
# Epoch 62/100
# 11610/11610 [==============================] - 1s 78us/sample - loss: 0.5933 - val_loss: 0.6527
# Epoch 63/100
# 11610/11610 [==============================] - 1s 78us/sample - loss: 0.5914 - val_loss: 0.6505
# Epoch 64/100
# 11610/11610 [==============================] - 1s 76us/sample - loss: 0.5895 - val_loss: 0.6484
# Epoch 65/100
# 11610/11610 [==============================] - 1s 78us/sample - loss: 0.5876 - val_loss: 0.6463
# Epoch 66/100
# 11610/11610 [==============================] - 1s 75us/sample - loss: 0.5858 - val_loss: 0.6442
# Epoch 67/100
# 11610/11610 [==============================] - 1s 77us/sample - loss: 0.5840 - val_loss: 0.6422
# Epoch 68/100
# 11610/11610 [==============================] - 1s 78us/sample - loss: 0.5822 - val_loss: 0.6401
# Epoch 69/100
# 11610/11610 [==============================] - 1s 77us/sample - loss: 0.5804 - val_loss: 0.6381
# Epoch 70/100
# 11610/11610 [==============================] - 1s 76us/sample - loss: 0.5787 - val_loss: 0.6362
# Epoch 71/100
# 11610/11610 [==============================] - 1s 75us/sample - loss: 0.5770 - val_loss: 0.6342
# Epoch 72/100
# 11610/11610 [==============================] - 1s 77us/sample - loss: 0.5753 - val_loss: 0.6323
# Epoch 73/100
# 11610/11610 [==============================] - 1s 75us/sample - loss: 0.5736 - val_loss: 0.6304
# Train on 11610 samples, validate on 3870 samples
# Epoch 1/100
# 11610/11610 [==============================] - 1s 105us/sample - loss: 5.5281 - val_loss: 3.6485
# Epoch 2/100
# 11610/11610 [==============================] - 1s 74us/sample - loss: 2.6330 - val_loss: 2.0992
# Epoch 3/100
# 11610/11610 [==============================] - 1s 73us/sample - loss: 1.7329 - val_loss: 1.5107
# Epoch 4/100
# 11610/11610 [==============================] - 1s 73us/sample - loss: 1.3252 - val_loss: 1.2041
# Epoch 5/100
# 11610/11610 [==============================] - 1s 72us/sample - loss: 1.0921 - val_loss: 1.0223
# Epoch 6/100
# 11610/11610 [==============================] - 1s 74us/sample - loss: 0.9469 - val_loss: 0.9098
# Epoch 7/100
# 11610/11610 [==============================] - 1s 74us/sample - loss: 0.8537 - val_loss: 0.8395
# Epoch 8/100
# 11610/11610 [==============================] - 1s 75us/sample - loss: 0.7921 - val_loss: 0.7946
# Epoch 9/100
# 11610/11610 [==============================] - 1s 75us/sample - loss: 0.7504 - val_loss: 0.7637
# Epoch 10/100
# 11610/11610 [==============================] - 1s 75us/sample - loss: 0.7207 - val_loss: 0.7413
# Epoch 11/100
# 11610/11610 [==============================] - 1s 73us/sample - loss: 0.6983 - val_loss: 0.7240
# Epoch 12/100
# 11610/11610 [==============================] - 1s 74us/sample - loss: 0.6806 - val_loss: 0.7100
# Epoch 13/100
# 11610/11610 [==============================] - 1s 72us/sample - loss: 0.6657 - val_loss: 0.6979
# Epoch 14/100
# 11610/11610 [==============================] - 1s 75us/sample - loss: 0.6527 - val_loss: 0.6872
# Epoch 15/100
# 11610/11610 [==============================] - 1s 71us/sample - loss: 0.6412 - val_loss: 0.6773
# Epoch 16/100
# 11610/11610 [==============================] - 1s 72us/sample - loss: 0.6307 - val_loss: 0.6681
# Epoch 17/100
# 11610/11610 [==============================] - 1s 75us/sample - loss: 0.6210 - val_loss: 0.6594
# Epoch 18/100
# 11610/11610 [==============================] - 1s 71us/sample - loss: 0.6121 - val_loss: 0.6511
# Epoch 19/100
# 11610/11610 [==============================] - 1s 76us/sample - loss: 0.6037 - val_loss: 0.6432
# Epoch 20/100
# 11610/11610 [==============================] - 1s 75us/sample - loss: 0.5960 - val_loss: 0.6356
# Epoch 21/100
# 11610/11610 [==============================] - 1s 76us/sample - loss: 0.5887 - val_loss: 0.6283
# Epoch 22/100
# 11610/11610 [==============================] - 1s 75us/sample - loss: 0.5818 - val_loss: 0.6215
# Epoch 23/100
# 11610/11610 [==============================] - 1s 71us/sample - loss: 0.5753 - val_loss: 0.6149
# Epoch 24/100
# 11610/11610 [==============================] - 1s 72us/sample - loss: 0.5691 - val_loss: 0.6087
# Epoch 25/100
# 11610/11610 [==============================] - 1s 74us/sample - loss: 0.5632 - val_loss: 0.6027
# Epoch 26/100
# 11610/11610 [==============================] - 1s 71us/sample - loss: 0.5578 - val_loss: 0.5970
# Epoch 27/100
# 11610/11610 [==============================] - 1s 72us/sample - loss: 0.5525 - val_loss: 0.5917
# Epoch 28/100
# 11610/11610 [==============================] - 1s 73us/sample - loss: 0.5476 - val_loss: 0.5865
# Epoch 29/100
# 11610/11610 [==============================] - 1s 71us/sample - loss: 0.5429 - val_loss: 0.5815
# Epoch 30/100
# 11610/11610 [==============================] - 1s 74us/sample - loss: 0.5384 - val_loss: 0.5769
# Epoch 31/100
# 11610/11610 [==============================] - 1s 74us/sample - loss: 0.5343 - val_loss: 0.5723
# Epoch 32/100
# 11610/11610 [==============================] - 1s 75us/sample - loss: 0.5303 - val_loss: 0.5679
# Epoch 33/100
# 11610/11610 [==============================] - 1s 74us/sample - loss: 0.5265 - val_loss: 0.5637
# Epoch 34/100
# 11610/11610 [==============================] - 1s 74us/sample - loss: 0.5230 - val_loss: 0.5598
# Epoch 35/100
# 11610/11610 [==============================] - 1s 75us/sample - loss: 0.5196 - val_loss: 0.5561
# Epoch 36/100
# 11610/11610 [==============================] - 1s 73us/sample - loss: 0.5164 - val_loss: 0.5526
# Epoch 37/100
# 11610/11610 [==============================] - 1s 73us/sample - loss: 0.5134 - val_loss: 0.5492
# Epoch 38/100
# 11610/11610 [==============================] - 1s 73us/sample - loss: 0.5105 - val_loss: 0.5460
# Epoch 39/100
# 11610/11610 [==============================] - 1s 73us/sample - loss: 0.5077 - val_loss: 0.5429
# Epoch 40/100
# 11610/11610 [==============================] - 1s 73us/sample - loss: 0.5050 - val_loss: 0.5400
# Epoch 41/100
# 11610/11610 [==============================] - 1s 74us/sample - loss: 0.5025 - val_loss: 0.5372
# Epoch 42/100
# 11610/11610 [==============================] - 1s 74us/sample - loss: 0.5001 - val_loss: 0.5345
# Epoch 43/100
# 11610/11610 [==============================] - 1s 71us/sample - loss: 0.4979 - val_loss: 0.5319
# Epoch 44/100
# 11610/11610 [==============================] - 1s 72us/sample - loss: 0.4957 - val_loss: 0.5294
# Epoch 45/100
# 11610/11610 [==============================] - 1s 73us/sample - loss: 0.4935 - val_loss: 0.5270
# Epoch 46/100
# 11610/11610 [==============================] - 1s 73us/sample - loss: 0.4915 - val_loss: 0.5246
# Epoch 47/100
# 11610/11610 [==============================] - 1s 74us/sample - loss: 0.4895 - val_loss: 0.5224
# Epoch 48/100
# 11610/11610 [==============================] - 1s 74us/sample - loss: 0.4876 - val_loss: 0.5203
# Epoch 49/100
# 11610/11610 [==============================] - 1s 74us/sample - loss: 0.4858 - val_loss: 0.5182
# Epoch 50/100
# 11610/11610 [==============================] - 1s 74us/sample - loss: 0.4841 - val_loss: 0.5161
# Epoch 51/100
# 11610/11610 [==============================] - 1s 71us/sample - loss: 0.4824 - val_loss: 0.5143
# Epoch 52/100
# 11610/11610 [==============================] - 1s 74us/sample - loss: 0.4808 - val_loss: 0.5124
# Epoch 53/100
# 11610/11610 [==============================] - 1s 72us/sample - loss: 0.4792 - val_loss: 0.5108
# Epoch 54/100
# 11610/11610 [==============================] - 1s 74us/sample - loss: 0.4777 - val_loss: 0.5090
# Epoch 55/100
# 11610/11610 [==============================] - 1s 74us/sample - loss: 0.4763 - val_loss: 0.5075
# Train on 11610 samples, validate on 3870 samples
# Epoch 1/100
# 11610/11610 [==============================] - 1s 108us/sample - loss: 1.8407 - val_loss: 0.8753
# Epoch 2/100
# 11610/11610 [==============================] - 1s 73us/sample - loss: 0.7434 - val_loss: 0.7635
# Epoch 3/100
# 11610/11610 [==============================] - 1s 72us/sample - loss: 0.6802 - val_loss: 0.7260
# Epoch 4/100
# 11610/11610 [==============================] - ETA: 0s - loss: 0.648 - 1s 75us/sample - loss: 0.6488 - val_loss: 0.6958
# Epoch 5/100
# 11610/11610 [==============================] - 1s 73us/sample - loss: 0.6230 - val_loss: 0.6692
# Epoch 6/100
# 11610/11610 [==============================] - 1s 76us/sample - loss: 0.6005 - val_loss: 0.6450
# Epoch 7/100
# 11610/11610 [==============================] - 1s 72us/sample - loss: 0.5807 - val_loss: 0.6245
# Epoch 8/100
# 11610/11610 [==============================] - 1s 70us/sample - loss: 0.5644 - val_loss: 0.6067
# Epoch 9/100
# 11610/11610 [==============================] - 1s 75us/sample - loss: 0.5496 - val_loss: 0.5930
# Epoch 10/100
# 11610/11610 [==============================] - 1s 71us/sample - loss: 0.5365 - val_loss: 0.5780
# Epoch 11/100
# 11610/11610 [==============================] - 1s 71us/sample - loss: 0.5265 - val_loss: 0.5667
# Epoch 12/100
# 11610/11610 [==============================] - 1s 74us/sample - loss: 0.5167 - val_loss: 0.5584
# Epoch 13/100
# 11610/11610 [==============================] - 1s 75us/sample - loss: 0.5080 - val_loss: 0.5458
# Epoch 14/100
# 11610/11610 [==============================] - 1s 71us/sample - loss: 0.5010 - val_loss: 0.5374
# Epoch 15/100
# 11610/11610 [==============================] - 1s 73us/sample - loss: 0.4948 - val_loss: 0.5312
# Epoch 16/100
# 11610/11610 [==============================] - 1s 73us/sample - loss: 0.4890 - val_loss: 0.5239
# Epoch 17/100
# 11610/11610 [==============================] - 1s 73us/sample - loss: 0.4834 - val_loss: 0.5178
# Epoch 18/100
# 11610/11610 [==============================] - 1s 71us/sample - loss: 0.4785 - val_loss: 0.5119
# Epoch 19/100
# 11610/11610 [==============================] - 1s 71us/sample - loss: 0.4739 - val_loss: 0.5096
# Epoch 20/100
# 11610/11610 [==============================] - 1s 71us/sample - loss: 0.4701 - val_loss: 0.5026
# Epoch 21/100
# 11610/11610 [==============================] - 1s 71us/sample - loss: 0.4663 - val_loss: 0.4989
# Epoch 22/100
# 11610/11610 [==============================] - 1s 72us/sample - loss: 0.4628 - val_loss: 0.4954
# Epoch 23/100
# 11610/11610 [==============================] - 1s 73us/sample - loss: 0.4593 - val_loss: 0.4930
# Epoch 24/100
# 11610/11610 [==============================] - 1s 74us/sample - loss: 0.4560 - val_loss: 0.4873
# Epoch 25/100
# 11610/11610 [==============================] - 1s 73us/sample - loss: 0.4531 - val_loss: 0.4838
# Epoch 26/100
# 11610/11610 [==============================] - 1s 74us/sample - loss: 0.4502 - val_loss: 0.4810
# Epoch 27/100
# 11610/11610 [==============================] - 1s 74us/sample - loss: 0.4476 - val_loss: 0.4784
# Epoch 28/100
# 11610/11610 [==============================] - 1s 73us/sample - loss: 0.4450 - val_loss: 0.4754
# Epoch 29/100
# 11610/11610 [==============================] - 1s 74us/sample - loss: 0.4427 - val_loss: 0.4731
# Epoch 30/100
# 11610/11610 [==============================] - 1s 71us/sample - loss: 0.4407 - val_loss: 0.4708
# Epoch 31/100
# 11610/11610 [==============================] - 1s 73us/sample - loss: 0.4384 - val_loss: 0.4673
# Epoch 32/100
# 11610/11610 [==============================] - 1s 71us/sample - loss: 0.4363 - val_loss: 0.4643
# Epoch 33/100
# 11610/11610 [==============================] - 1s 74us/sample - loss: 0.4346 - val_loss: 0.4641
# Epoch 34/100
# 11610/11610 [==============================] - 1s 76us/sample - loss: 0.4328 - val_loss: 0.4613
# Epoch 35/100
# 11610/11610 [==============================] - 1s 72us/sample - loss: 0.4310 - val_loss: 0.4589
# Epoch 36/100
# 11610/11610 [==============================] - 1s 75us/sample - loss: 0.4291 - val_loss: 0.4569
# Epoch 37/100
# 11610/11610 [==============================] - 1s 74us/sample - loss: 0.4273 - val_loss: 0.4547
# Train on 11610 samples, validate on 3870 samples
# Epoch 1/100
# 11610/11610 [==============================] - 1s 101us/sample - loss: 1.7833 - val_loss: 0.7880
# Epoch 2/100
# 11610/11610 [==============================] - 1s 72us/sample - loss: 0.6395 - val_loss: 0.6066
# Epoch 3/100
# 11610/11610 [==============================] - 1s 73us/sample - loss: 0.5507 - val_loss: 0.5627
# Epoch 4/100
# 11610/11610 [==============================] - 1s 73us/sample - loss: 0.5164 - val_loss: 0.5393
# Epoch 5/100
# 11610/11610 [==============================] - 1s 73us/sample - loss: 0.4978 - val_loss: 0.5246
# Epoch 6/100
# 11610/11610 [==============================] - 1s 73us/sample - loss: 0.4877 - val_loss: 0.5131
# Epoch 7/100
# 11610/11610 [==============================] - 1s 71us/sample - loss: 0.4786 - val_loss: 0.4992
# Epoch 8/100
# 11610/11610 [==============================] - 1s 74us/sample - loss: 0.4705 - val_loss: 0.4930
# Epoch 9/100
# 11610/11610 [==============================] - 1s 71us/sample - loss: 0.4659 - val_loss: 0.4860
# Epoch 10/100
# 11610/11610 [==============================] - 1s 73us/sample - loss: 0.4589 - val_loss: 0.4785
# Epoch 11/100
# 11610/11610 [==============================] - 1s 73us/sample - loss: 0.4558 - val_loss: 0.4709
# Epoch 12/100
# 11610/11610 [==============================] - 1s 71us/sample - loss: 0.4463 - val_loss: 0.4655
# Epoch 13/100
# 11610/11610 [==============================] - 1s 73us/sample - loss: 0.4407 - val_loss: 0.4635
# Epoch 14/100
# 11610/11610 [==============================] - 1s 71us/sample - loss: 0.4364 - val_loss: 0.4558
# Epoch 15/100
# 11610/11610 [==============================] - 1s 73us/sample - loss: 0.4318 - val_loss: 0.4563
# Epoch 16/100
# 11610/11610 [==============================] - 1s 71us/sample - loss: 0.4288 - val_loss: 0.4485
# Epoch 17/100
# 11610/11610 [==============================] - 1s 74us/sample - loss: 0.4247 - val_loss: 0.4459
# Epoch 18/100
# 11610/11610 [==============================] - 1s 73us/sample - loss: 0.4196 - val_loss: 0.4428
# Epoch 19/100
# 11610/11610 [==============================] - 1s 73us/sample - loss: 0.4148 - val_loss: 0.4354
# Epoch 20/100
# 11610/11610 [==============================] - 1s 72us/sample - loss: 0.4119 - val_loss: 0.4300
# Epoch 21/100
# 11610/11610 [==============================] - 1s 71us/sample - loss: 0.4098 - val_loss: 0.4248
# Epoch 22/100
# 11610/11610 [==============================] - 1s 73us/sample - loss: 0.4051 - val_loss: 0.4225
# Epoch 23/100
# 11610/11610 [==============================] - 1s 71us/sample - loss: 0.4034 - val_loss: 0.4237
# Epoch 24/100
# 11610/11610 [==============================] - 1s 74us/sample - loss: 0.3994 - val_loss: 0.4160
# Epoch 25/100
# 11610/11610 [==============================] - 1s 71us/sample - loss: 0.3986 - val_loss: 0.4127
# Epoch 26/100
# 11610/11610 [==============================] - 1s 73us/sample - loss: 0.3944 - val_loss: 0.4087
# Epoch 27/100
# 11610/11610 [==============================] - 1s 73us/sample - loss: 0.3915 - val_loss: 0.4125
# Epoch 28/100
# 11610/11610 [==============================] - 1s 73us/sample - loss: 0.3894 - val_loss: 0.4079
# Epoch 29/100
# 11610/11610 [==============================] - 1s 73us/sample - loss: 0.3897 - val_loss: 0.4016
# Epoch 30/100
# 11610/11610 [==============================] - 1s 73us/sample - loss: 0.3857 - val_loss: 0.4013
# Epoch 31/100
# 11610/11610 [==============================] - 1s 73us/sample - loss: 0.3839 - val_loss: 0.4006
# Epoch 32/100
# 11610/11610 [==============================] - 1s 71us/sample - loss: 0.3835 - val_loss: 0.4010
# Epoch 33/100
# 11610/11610 [==============================] - 1s 73us/sample - loss: 0.3832 - val_loss: 0.3974
# Epoch 34/100
# 11610/11610 [==============================] - 1s 73us/sample - loss: 0.3821 - val_loss: 0.3923
# Train on 11610 samples, validate on 3870 samples
# Epoch 1/100
# 11610/11610 [==============================] - 1s 101us/sample - loss: 1.3067 - val_loss: 0.5405
# Epoch 2/100
# 11610/11610 [==============================] - 1s 74us/sample - loss: 0.4696 - val_loss: 0.9066
# Epoch 3/100
# 11610/11610 [==============================] - 1s 72us/sample - loss: 0.4440 - val_loss: 0.4409
# Epoch 4/100
# 11610/11610 [==============================] - 1s 74us/sample - loss: 0.4083 - val_loss: 0.4175
# Epoch 5/100
# 11610/11610 [==============================] - 1s 71us/sample - loss: 0.3934 - val_loss: 0.4046
# Epoch 6/100
# 11610/11610 [==============================] - 1s 74us/sample - loss: 0.3894 - val_loss: 0.4031
# Epoch 7/100
# 11610/11610 [==============================] - 1s 71us/sample - loss: 0.3833 - val_loss: 0.3962
# Epoch 8/100
# 11610/11610 [==============================] - 1s 71us/sample - loss: 0.3791 - val_loss: 0.3874
# Epoch 9/100
# 11610/11610 [==============================] - 1s 72us/sample - loss: 0.3744 - val_loss: 0.3849
# Epoch 10/100
# 11610/11610 [==============================] - 1s 74us/sample - loss: 0.3729 - val_loss: 0.3792
# Epoch 11/100
# 11610/11610 [==============================] - 1s 74us/sample - loss: 0.3701 - val_loss: 0.3845
# Epoch 12/100
# 11610/11610 [==============================] - 1s 72us/sample - loss: 0.3690 - val_loss: 0.3767
# Epoch 13/100
# 11610/11610 [==============================] - 1s 73us/sample - loss: 0.3651 - val_loss: 0.4017
# Epoch 14/100
# 11610/11610 [==============================] - 1s 73us/sample - loss: 0.3906 - val_loss: 0.3729
# Epoch 15/100
# 11610/11610 [==============================] - 1s 73us/sample - loss: 0.3670 - val_loss: 0.3754
# Epoch 16/100
# 11610/11610 [==============================] - 1s 72us/sample - loss: 0.3660 - val_loss: 0.3688
# Epoch 17/100
# 11610/11610 [==============================] - 1s 73us/sample - loss: 0.3571 - val_loss: 0.3662
# Epoch 18/100
# 11610/11610 [==============================] - 1s 71us/sample - loss: 0.3555 - val_loss: 0.3636
# Epoch 19/100
# 11610/11610 [==============================] - 1s 74us/sample - loss: 0.3540 - val_loss: 0.3680
# Epoch 20/100
# 11610/11610 [==============================] - 1s 72us/sample - loss: 0.3518 - val_loss: 0.3600
# Epoch 21/100
# 11610/11610 [==============================] - 1s 71us/sample - loss: 0.3479 - val_loss: 0.3707
# Epoch 22/100
# 11610/11610 [==============================] - 1s 72us/sample - loss: 0.3445 - val_loss: 0.3617
# Train on 11610 samples, validate on 3870 samples
# Epoch 1/100
# 11610/11610 [==============================] - 1s 102us/sample - loss: 1.1422 - val_loss: 22.2697
# Epoch 2/100
# 11610/11610 [==============================] - 1s 72us/sample - loss: nan - val_loss: nan
# Epoch 3/100
# 11610/11610 [==============================] - 1s 72us/sample - loss: nan - val_loss: nan
# Epoch 4/100
# 11610/11610 [==============================] - 1s 73us/sample - loss: nan - val_loss: nan
# Epoch 5/100
# 11610/11610 [==============================] - 1s 73us/sample - loss: nan - val_loss: nan
# Epoch 6/100
# 11610/11610 [==============================] - 1s 71us/sample - loss: nan - val_loss: nan

# %%
def plot_learning_curves(history):
    pd.DataFrame(history.history).plot(figsize=(8,5))
    plt.grid(True)
    plt.gca().set_ylim(0,1)
    plt.show()
for lr, history in zip(learning_rate, histories):
    print('Learning rate: ', lr)
    plot_learning_curves(history)
# Out:
# Learning rate:  0.0001
# Learning rate:  0.0003
# Learning rate:  0.001
# Learning rate:  0.003
# Learning rate:  0.01
# Learning rate:  0.03

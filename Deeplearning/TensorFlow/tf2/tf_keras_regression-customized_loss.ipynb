# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import sklearn
import pandas as pd
import os
import sys
import time
import tensorflow as tf
from tensorflow import keras
from sklearn.datasets import fetch_california_housing

print(tf.__version__)
print(sys.version_info)
for module in mpl, np, pd, sklearn, tf, keras:
    print(module.__name__, module.__version__)
# Out:
# 2.0.0
# sys.version_info(major=3, minor=6, micro=5, releaselevel='final', serial=0)
# matplotlib 3.1.0
# numpy 1.17.4
# pandas 0.24.2
# sklearn 0.20.1
# tensorflow 2.0.0
# tensorflow_core.keras 2.2.4-tf

# %%
house = fetch_california_housing()
print(house.DESCR)
# Out:
# Downloading Cal. housing from https://ndownloader.figshare.com/files/5976036 to /home/kdd/scikit_learn_data
# .. _california_housing_dataset:
#
# California Housing dataset
# --------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 20640
#
#     :Number of Attributes: 8 numeric, predictive attributes and the target
#
#     :Attribute Information:
#         - MedInc        median income in block
#         - HouseAge      median house age in block
#         - AveRooms      average number of rooms
#         - AveBedrms     average number of bedrooms
#         - Population    block population
#         - AveOccup      average house occupancy
#         - Latitude      house block latitude
#         - Longitude     house block longitude
#
#     :Missing Attribute Values: None
#
# This dataset was obtained from the StatLib repository.
# http://lib.stat.cmu.edu/datasets/
#
# The target variable is the median house value for California districts.
#
# This dataset was derived from the 1990 U.S. census, using one row per census
# block group. A block group is the smallest geographical unit for which the U.S.
# Census Bureau publishes sample data (a block group typically has a population
# of 600 to 3,000 people).
#
# It can be downloaded/loaded using the
# :func:`sklearn.datasets.fetch_california_housing` function.
#
# .. topic:: References
#
#     - Pace, R. Kelley and Ronald Barry, Sparse Spatial Autoregressions,
#       Statistics and Probability Letters, 33 (1997) 291-297

# %%
house.data.shape, house.target.shape
# Out:
# ((20640, 8), (20640,))

# %%
from sklearn.model_selection import train_test_split

x_train_all, x_test, y_train_all, y_test = train_test_split(
    house.data, house.target, random_state=7)
x_train, x_valid, y_train, y_valid = train_test_split(
    x_train_all, y_train_all, random_state=11)
print(x_train.shape, y_train.shape)
print(x_test.shape, y_test.shape)
print(x_valid.shape, y_valid.shape)
# Out:
# (11610, 8) (11610,)
# (5160, 8) (5160,)
# (3870, 8) (3870,)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)
x_valid_scaled = scaler.transform(x_valid)
x_test_scaled = scaler.transform(x_test)

# %%
def customized_loss(y_true, y_pred):
    return tf.reduce_mean(tf.square(y_true - y_pred))

model = keras.Sequential([
    keras.layers.Dense(30, activation='relu', input_shape=x_train.shape[1:]),
    keras.layers.Dense(1)
])
model.summary()
model.compile(loss=customized_loss, optimizer='sgd', metrics=['mean_squared_error'])
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_2 (Dense)              (None, 30)                270
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 31
# =================================================================
# Total params: 301
# Trainable params: 301
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(x_train_scaled, y_train,
                   validation_data=(x_valid_scaled, y_valid),
                   epochs=100,
                   callbacks=[keras.callbacks.EarlyStopping(patience=5, min_delta=1e-3)])
# Out:
# Train on 11610 samples, validate on 3870 samples
# Epoch 1/100
# 11610/11610 [==============================] - 1s 54us/sample - loss: 0.9100 - mean_squared_error: 0.9100 - val_loss: 0.5958 - val_mean_squared_error: 0.5958
# Epoch 2/100
# 11610/11610 [==============================] - 0s 28us/sample - loss: 0.5142 - mean_squared_error: 0.5142 - val_loss: 0.4834 - val_mean_squared_error: 0.4834
# Epoch 3/100
# 11610/11610 [==============================] - 0s 30us/sample - loss: 0.4501 - mean_squared_error: 0.4501 - val_loss: 0.4569 - val_mean_squared_error: 0.4569
# Epoch 4/100
# 11610/11610 [==============================] - 0s 29us/sample - loss: 0.4328 - mean_squared_error: 0.4328 - val_loss: 0.4399 - val_mean_squared_error: 0.4399
# Epoch 5/100
# 11610/11610 [==============================] - 0s 28us/sample - loss: 0.4210 - mean_squared_error: 0.4210 - val_loss: 0.4325 - val_mean_squared_error: 0.4325
# Epoch 6/100
# 11610/11610 [==============================] - 0s 28us/sample - loss: 0.4113 - mean_squared_error: 0.4113 - val_loss: 0.4195 - val_mean_squared_error: 0.4195
# Epoch 7/100
# 11610/11610 [==============================] - 0s 28us/sample - loss: 0.4085 - mean_squared_error: 0.4085 - val_loss: 0.4476 - val_mean_squared_error: 0.4476
# Epoch 8/100
# 11610/11610 [==============================] - 0s 28us/sample - loss: 0.3982 - mean_squared_error: 0.3982 - val_loss: 0.4095 - val_mean_squared_error: 0.4095
# Epoch 9/100
# 11610/11610 [==============================] - 0s 28us/sample - loss: 0.3916 - mean_squared_error: 0.3916 - val_loss: 0.3998 - val_mean_squared_error: 0.3998
# Epoch 10/100
# 11610/11610 [==============================] - 0s 28us/sample - loss: 0.3851 - mean_squared_error: 0.3851 - val_loss: 0.4017 - val_mean_squared_error: 0.4017
# Epoch 11/100
# 11610/11610 [==============================] - 0s 28us/sample - loss: 0.3814 - mean_squared_error: 0.3814 - val_loss: 0.3925 - val_mean_squared_error: 0.3925
# Epoch 12/100
# 11610/11610 [==============================] - 0s 28us/sample - loss: 0.3849 - mean_squared_error: 0.3849 - val_loss: 0.3910 - val_mean_squared_error: 0.3910
# Epoch 13/100
# 11610/11610 [==============================] - 0s 28us/sample - loss: 0.3757 - mean_squared_error: 0.3757 - val_loss: 0.3989 - val_mean_squared_error: 0.3989
# Epoch 14/100
# 11610/11610 [==============================] - 0s 28us/sample - loss: 0.3751 - mean_squared_error: 0.3751 - val_loss: 0.4307 - val_mean_squared_error: 0.4307
# Epoch 15/100
# 11610/11610 [==============================] - 0s 28us/sample - loss: 0.4098 - mean_squared_error: 0.4098 - val_loss: 0.3920 - val_mean_squared_error: 0.3920
# Epoch 16/100
# 11610/11610 [==============================] - 0s 29us/sample - loss: 0.3868 - mean_squared_error: 0.3868 - val_loss: 0.3868 - val_mean_squared_error: 0.3868
# Epoch 17/100
# 11610/11610 [==============================] - 0s 28us/sample - loss: 0.3713 - mean_squared_error: 0.3713 - val_loss: 0.3851 - val_mean_squared_error: 0.3851
# Epoch 18/100
# 11610/11610 [==============================] - 0s 28us/sample - loss: 0.3722 - mean_squared_error: 0.3722 - val_loss: 0.3790 - val_mean_squared_error: 0.3790
# Epoch 19/100
# 11610/11610 [==============================] - 0s 28us/sample - loss: 0.3836 - mean_squared_error: 0.3836 - val_loss: 0.3801 - val_mean_squared_error: 0.3801
# Epoch 20/100
# 11610/11610 [==============================] - 0s 28us/sample - loss: 0.3651 - mean_squared_error: 0.3651 - val_loss: 0.3888 - val_mean_squared_error: 0.3888
# Epoch 21/100
# 11610/11610 [==============================] - 0s 28us/sample - loss: 0.3809 - mean_squared_error: 0.3809 - val_loss: 0.3756 - val_mean_squared_error: 0.3756
# Epoch 22/100
# 11610/11610 [==============================] - 0s 28us/sample - loss: 0.3627 - mean_squared_error: 0.3627 - val_loss: 0.3747 - val_mean_squared_error: 0.3747
# Epoch 23/100
# 11610/11610 [==============================] - 0s 28us/sample - loss: 0.3598 - mean_squared_error: 0.3598 - val_loss: 0.3716 - val_mean_squared_error: 0.3716
# Epoch 24/100
# 11610/11610 [==============================] - 0s 28us/sample - loss: 0.3606 - mean_squared_error: 0.3606 - val_loss: 0.3667 - val_mean_squared_error: 0.3667
# Epoch 25/100
# 11610/11610 [==============================] - 0s 28us/sample - loss: 0.3571 - mean_squared_error: 0.3571 - val_loss: 0.3678 - val_mean_squared_error: 0.3678
# Epoch 26/100
# 11610/11610 [==============================] - 0s 28us/sample - loss: 0.3585 - mean_squared_error: 0.3585 - val_loss: 0.3659 - val_mean_squared_error: 0.3659
# Epoch 27/100
# 11610/11610 [==============================] - 0s 28us/sample - loss: 0.3620 - mean_squared_error: 0.3620 - val_loss: 0.3683 - val_mean_squared_error: 0.3683
# Epoch 28/100
# 11610/11610 [==============================] - 0s 28us/sample - loss: 0.3601 - mean_squared_error: 0.3601 - val_loss: 0.3699 - val_mean_squared_error: 0.3699
# Epoch 29/100
# 11610/11610 [==============================] - 0s 28us/sample - loss: 0.3518 - mean_squared_error: 0.3518 - val_loss: 0.3667 - val_mean_squared_error: 0.3667

# %%
def plot_learning_curves(history):
    pd.DataFrame(history.history).plot(figsize=(8,5))
    plt.grid(True)
    plt.gca().set_ylim(0,1)
    plt.show()
plot_learning_curves(history)

# %%
model.evaluate(x_test_scaled, y_test)
# Out:
# 5160/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================== ...
# [0.37508807709050734, 0.3750881]

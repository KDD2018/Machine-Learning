# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import sklearn
import pandas as pd
import os
import sys
import time
import tensorflow as tf
from tensorflow import keras
from sklearn.datasets import fetch_california_housing

print(tf.__version__)
print(sys.version_info)
for module in mpl, np, pd, sklearn, tf, keras:
    print(module.__name__, module.__version__)
# Out:
# 2.0.0
# sys.version_info(major=3, minor=6, micro=8, releaselevel='final', serial=0)
# matplotlib 3.1.1
# numpy 1.17.2
# pandas 0.25.3
# sklearn 0.21.3
# tensorflow 2.0.0
# tensorflow_core.keras 2.2.4-tf

# %%
house = fetch_california_housing()
print(house.DESCR)
# Out:
# .. _california_housing_dataset:
#
# California Housing dataset
# --------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 20640
#
#     :Number of Attributes: 8 numeric, predictive attributes and the target
#
#     :Attribute Information:
#         - MedInc        median income in block
#         - HouseAge      median house age in block
#         - AveRooms      average number of rooms
#         - AveBedrms     average number of bedrooms
#         - Population    block population
#         - AveOccup      average house occupancy
#         - Latitude      house block latitude
#         - Longitude     house block longitude
#
#     :Missing Attribute Values: None
#
# This dataset was obtained from the StatLib repository.
# http://lib.stat.cmu.edu/datasets/
#
# The target variable is the median house value for California districts.
#
# This dataset was derived from the 1990 U.S. census, using one row per census
# block group. A block group is the smallest geographical unit for which the U.S.
# Census Bureau publishes sample data (a block group typically has a population
# of 600 to 3,000 people).
#
# It can be downloaded/loaded using the
# :func:`sklearn.datasets.fetch_california_housing` function.
#
# .. topic:: References
#
#     - Pace, R. Kelley and Ronald Barry, Sparse Spatial Autoregressions,
#       Statistics and Probability Letters, 33 (1997) 291-297

# %%
from sklearn.model_selection import train_test_split

x_train_all, x_test, y_train_all, y_test = train_test_split(
    house.data, house.target, random_state=7)
x_train, x_valid, y_train, y_valid = train_test_split(
    x_train_all, y_train_all, random_state=11)
print(x_train.shape, y_train.shape)
print(x_test.shape, y_test.shape)
print(x_valid.shape, y_valid.shape)
# Out:
# (11610, 8) (11610,)
# (5160, 8) (5160,)
# (3870, 8) (3870,)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)
x_valid_scaled = scaler.transform(x_valid)
x_test_scaled = scaler.transform(x_test)

# %%
# fit函数功能
# 1、batch 遍历训练集 metric
   # 1.1、自动求导
# 2、在epoch结束 验证模型 metric
'''自定义fit函数功能'''

epochs = 100
batch_size = 32
steps_per_epoch = len(x_train_scaled) // batch_size
optimizer = keras.optimizers.SGD()
metric = keras.metrics.MeanSquaredError()

# 随机获取大小为batch_size的数据
def random_batch(x, y, batch_size=32):
    idx = np.random.randint(0, len(x), size=batch_size)
    return x[idx], y[idx]

model = keras.Sequential([
    keras.layers.Dense(30, activation='relu', input_shape=x_train.shape[1:]),
    keras.layers.Dense(1)
])

for epoch in range(epochs):
    metric.reset_states()
    for step in range(steps_per_epoch):
        x_batch, y_batch = random_batch(x_train_scaled, y_train, batch_size)
        with tf.GradientTape() as tape:
            y_pred = model(x_batch)
            loss = tf.reduce_mean(keras.losses.mean_squared_error(y_batch, y_pred))
            metric(y_batch, y_pred)
        grads = tape.gradient(loss, model.variables)
        grads_and_vars = zip(grads, model.variables)
        optimizer.apply_gradients(grads_and_vars)
        print('\rEpoch: ', epoch, 'train mse: ', metric.result().numpy(), end='')
    y_valid_pred = model(x_valid_scaled)
    valid_loss = tf.reduce_mean(keras.losses.mean_squared_error(y_valid, y_valid_pred))
    print('\t', 'valid mse: ', valid_loss.numpy())
# Out:
# WARNING:tensorflow:Layer dense is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# Epoch:  0 train mse:  1.3773888	 valid mse:  1.4331329
# Epoch:  1 train mse:  1.2802105	 valid mse:  1.4124469train mse:  1.28317
# Epoch:  2 train mse:  1.2933694	 valid mse:  1.4007927
# Epoch:  3 train mse:  1.2593651	 valid mse:  1.3941729
# Epoch:  4 train mse:  1.2746284	 valid mse:  1.3917522
# Epoch:  5 train mse:  1.2801796	 valid mse:  1.3884748
# Epoch:  6 train mse:  1.2720705	 valid mse:  1.3870445
# Epoch:  7 train mse:  1.2639405	 valid mse:  1.4060624rain mse:  1.2682015
# Epoch:  8 train mse:  1.2267271	 valid mse:  1.387971
# Epoch:  9 train mse:  1.2181292	 valid mse:  1.4089633
# Epoch:  10 train mse:  1.2766117	 valid mse:  1.3929198
# Epoch:  11 train mse:  1.25325185 train mse:  1.2038774	 valid mse:  1.3849249
# Epoch:  12 train mse:  1.263731	 valid mse:  1.3970174
# Epoch:  13 train mse:  1.2578728	 valid mse:  1.386619
# Epoch:  14 train mse:  1.28156231.2900494	 valid mse:  1.3843943
# Epoch:  15 train mse:  1.2455279	 valid mse:  1.3865373
# Epoch:  16 train mse:  1.2374439	 valid mse:  1.387764
# Epoch:  17 train mse:  1.2555228	 valid mse:  1.3861424
# Epoch:  18 train mse:  1.27774875	 valid mse:  1.3945923
# Epoch:  19 train mse:  1.2669169	 valid mse:  1.38373516327
# Epoch:  20 train mse:  1.270711	 valid mse:  1.383792
# Epoch:  21 train mse:  1.2792813	 valid mse:  1.38524173050001
# Epoch:  22 train mse:  1.2580987	 valid mse:  1.3843445
# Epoch:  23 train mse:  1.2604744	 valid mse:  1.3868306
# Epoch:  24 train mse:  1.2348045	 valid mse:  1.3887101
# Epoch:  25 train mse:  1.259589	 valid mse:  1.3867832
# Epoch:  26 train mse:  1.2412871	 valid mse:  1.3868526
# Epoch:  27 train mse:  1.2494413	 valid mse:  1.3856407
# Epoch:  28 train mse:  1.2513982	 valid mse:  1.3951572
# Epoch:  29 train mse:  1.2624243	 valid mse:  1.3835504
# Epoch:  30 train mse:  1.2558333	 valid mse:  1.3842882
# Epoch:  31 train mse:  1.2270182	 valid mse:  1.3986938
# Epoch:  32 train mse:  1.2472614	 valid mse:  1.3905368
# Epoch:  33 train mse:  1.2443877	 valid mse:  1.3879013
# Epoch:  34 train mse:  1.2666115	 valid mse:  1.3841546
# Epoch:  35 train mse:  1.2585102	 valid mse:  1.3836172
# Epoch:  36 train mse:  1.2427765	 valid mse:  1.3860073
# Epoch:  37 train mse:  1.2317458	 valid mse:  1.3871882
# Epoch:  38 train mse:  1.2666469	 valid mse:  1.3853272rain mse:  1.2933675
# Epoch:  39 train mse:  1.2653842	 valid mse:  1.3838458
# Epoch:  40 train mse:  1.2632295	 valid mse:  1.3885206
# Epoch:  41 train mse:  1.2660794	 valid mse:  1.3846549
# Epoch:  42 train mse:  1.242312	 valid mse:  1.3841822
# Epoch:  43 train mse:  1.3057349	 valid mse:  1.3878134
# Epoch:  44 train mse:  1.2530729	 valid mse:  1.3848716
# Epoch:  45 train mse:  1.2588301	 valid mse:  1.3914992
# Epoch:  46 train mse:  1.24858191.2654641train mse:  1.2495079	 valid mse:  1.3835999
# Epoch:  47 train mse:  1.2456762	 valid mse:  1.3848102
# Epoch:  48 train mse:  1.2498701	 valid mse:  1.3906177
# Epoch:  49 train mse:  1.2814624	 valid mse:  1.3865733
# Epoch:  50 train mse:  1.2500806	 valid mse:  1.3849032
# Epoch:  51 train mse:  1.2237055	 valid mse:  1.3845613
# Epoch:  52 train mse:  1.2088563	 valid mse:  1.3938845
# Epoch:  53 train mse:  1.2522873	 valid mse:  1.3843669
# Epoch:  54 train mse:  1.2334859	 valid mse:  1.3884822
# Epoch:  55 train mse:  1.2984807	 valid mse:  1.383299
# Epoch:  56 train mse:  1.2267	 valid mse:  1.393472474
# Epoch:  57 train mse:  1.2604392	 valid mse:  1.3857148
# Epoch:  58 train mse:  1.2646317	 valid mse:  1.3844869
# Epoch:  59 train mse:  1.2475036	 valid mse:  1.38354681.2385486 1.2366071
# Epoch:  60 train mse:  1.2439368	 valid mse:  1.3836498
# Epoch:  61 train mse:  1.2590691	 valid mse:  1.3832526
# Epoch:  62 train mse:  1.2323785	 valid mse:  1.3842264
# Epoch:  63 train mse:  1.252479	 valid mse:  1.3853925
# Epoch:  64 train mse:  1.2353811	 valid mse:  1.383923
# Epoch:  65 train mse:  1.2681845	 valid mse:  1.3953705
# Epoch:  66 train mse:  1.2358688	 valid mse:  1.38626
# Epoch:  67 train mse:  1.270528	 valid mse:  1.3829322
# Epoch:  68 train mse:  1.2701076	 valid mse:  1.3830961
# Epoch:  69 train mse:  1.2529418	 valid mse:  1.390217
# Epoch:  70 train mse:  1.2891064	 valid mse:  1.3830196
# Epoch:  71 train mse:  1.2507807	 valid mse:  1.3833702
# Epoch:  72 train mse:  1.2511774	 valid mse:  1.3856435
# Epoch:  73 train mse:  1.2421645	 valid mse:  1.3836596
# Epoch:  74 train mse:  1.250301	 valid mse:  1.383266
# Epoch:  75 train mse:  1.2761751	 valid mse:  1.3836234
# Epoch:  76 train mse:  1.2358551	 valid mse:  1.3832566
# Epoch:  77 train mse:  1.2505393	 valid mse:  1.3964043
# Epoch:  78 train mse:  1.2418643train mse:  1.2463827	 valid mse:  1.3871185
# Epoch:  79 train mse:  1.2198157	 valid mse:  1.3836423
# Epoch:  80 train mse:  1.2453699	 valid mse:  1.3840041
# Epoch:  81 train mse:  1.2734001 1.2697502	 valid mse:  1.3840305
# Epoch:  82 train mse:  1.2335647	 valid mse:  1.3837986
# Epoch:  83 train mse:  1.2492262	 valid mse:  1.3874619
# Epoch:  84 train mse:  1.2094992	 valid mse:  1.3884512
# Epoch:  85 train mse:  1.2660412	 valid mse:  1.3828087ain mse:  1.2703775
# Epoch:  86 train mse:  1.2552463	 valid mse:  1.3852845
# Epoch:  87 train mse:  1.2580423	 valid mse:  1.3836474
# Epoch:  88 train mse:  1.2366524	 valid mse:  1.387824
# Epoch:  89 train mse:  1.2828633	 valid mse:  1.3848162
# Epoch:  90 train mse:  1.2723445	 valid mse:  1.3831526
# Epoch:  91 train mse:  1.2455049	 valid mse:  1.3834175
# Epoch:  92 train mse:  1.2707484	 valid mse:  1.3872333
# Epoch:  93 train mse:  1.2403313	 valid mse:  1.38397742416949
# Epoch:  94 train mse:  1.2556499	 valid mse:  1.38478782565153
# Epoch:  95 train mse:  1.2644666	 valid mse:  1.3859016
# Epoch:  96 train mse:  1.2615815	 valid mse:  1.3862127
# Epoch:  97 train mse:  1.2539847	 valid mse:  1.3857503
# Epoch:  98 train mse:  1.2493168	 valid mse:  1.3827167
# Epoch:  99 train mse:  1.2802272	 valid mse:  1.3872287
